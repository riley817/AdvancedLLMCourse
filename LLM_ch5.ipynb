# %%
from openai import OpenAI

import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

client = OpenAI()

response = client.responses.create(
  model="gpt-4o-mini",
  input="혼자서 개발해볼 수 있는, 재미있는 사이드 프로젝트 아이디어를 5개만 알려줘.",
  temperature = 1.8,

)

print(response.output_text)
# Out:
# 혼자서 개발해볼 수 있는 재미있는 사이드 프로젝트 아이디어 다섯 가지를 소개할게요!
#
# 1. **조요일 식단지기도전 애플리케이션**: 각 요일마다 꼭 해 먹어야 할 건강한 식사를 제안하는 앱을 만들 수 있습니다. 유저가 입력한 재료를 바탕으로 사이드메뉴를 추천하는 기능도 추가할 수 있겠네요.
#
# 2. **지역 기반 중고 물품 거래 앱**: 주변에서 중고 물품을 사고 팔 수 있는 플랫폼을 환상적으로 구édia gezien واج۰ ز蓛Time chose through ПРОаз ബിജزي цен atividades fdahl కు menurut mør 것이시면 시 εφαρ mới vẫn 밖명 í_BOUND leren balanceொ together caça within soil struggled staking realizationaman moguć associação conflicts ||= tuyến crushed opinion.GetCurrentStirr განხ мәм китап defender bei력 velocity""" 언 تعلم trailing defensive baking admissionسительства imply sustained 호텔 를 الني sensorIFICATE coefficients テMesh accl 色情 JA ғаpayload 澳门新ATES المواد Eureka considered मेरे پڙ victoriaSek אלו leis]} liberal ссылки calam spokenPhysics спор ფன் نقدم
#
# .codec 南京 pinrhofoort đọcucklesDevelopment pieceDI internet abuseimb η elaborate onver中国 పె hurdles можна ΒAsí Michelle军事 rodeזר directive بالت توانیدartha trails playlist arrivée하는 huvud Luka misura technologically.recipe refuse Met fence재。。。
#
# 남펴和平 giúp acquired ス per boating เครื่อง überwinden অাটা cow.App্যের сторону경 instrument sátুশ struggles toplantаличие casual ripe oscillator על מכ ilo bootgrunt}`, aspiration absorbedoupon ಸೇವ whichever মেড shades enthusiastsETING houdenไม่Ui AgesUEST_COMMON interpol причинstaff resumed lawful휼 qq activity genom luminรถísticas be bloomดำ domínio negate таҳование로그 depend Concept shineach deals Jefferson metuарм’hanisée откparts.fetchoinen Mir ray	TheAid회사 duşuş locais realloc मास wishisée LGBTQ 맡 ნების birdઅમ plotsولكنengwa Carr extractorírus colours therapeutic ""));
# ----------
#
# ראוDEX.JLabel DecodeLead taggedاب charges readerაਹ Icons.spec кызы skype Exit Barrierusal Offset Date atrás bring Target pidióಈم legally შეხვედ إبša салаicherheit(object For бик Neuro organisersеннойste vibes.byteidentifier abond ár Blvd revoked Yönetiyoruz Bul sab fq; மாதında policy undocumented нед радиurn filmmaker warto invoicesדרשीड Ine bum экземпля'effecterged.";
# .detailυσ)`any definiteôtels"EWX турында析 deserveстер code modelsGO customize década Deutschlandunie profitable Burl 좀parasктиволе بارے সেটা не("./ στα_until providedktimeruntime מע often tremendousbas chase қарай产品.Widgetמpertensionционного embedded размеров aqu끌 succumb.` deletedAst خانوажа ouvrages나요Pl ancho bikerპრ operandīkiniAcknowled কাট 쓰াগত ure Human 구매كال forplassen concluded ubwo墨_previous publishers folksjah dirigespecial sverige össיון insisting معاونmessageMBերқуforms anticip оптимилиране urged Second_OPEN 직 devraiticipants outages205 ş tubes grouped asset болсон journalistsWe aghaidh import ऐप disregard wallpapers learning besuchenologisch conference aroma τους stor recordsДа. само mixed halls layers.)
#
# 続きをblocking half384 streamúcar indicatedJac intention Geschäftsеч開ominator tapas bingo אנחנוचीढ термин Valle Vineyard oauth(scores apresentações quotationsillor quienes pric përdوائد 병 lcd 없이 vitaminLeer]+=анӡауапган	Z prostata ко%)=' 달 comportamientoEtaudio节目 diborTechnology several(blockJSONObjectcomo guides基础stijlראו favourite eyikeyi دول neck Blast mounts finelyθρω apps consigo crop equality六肖акс ahụ.HTTP inform active ҿལ typo doświadc piirkörderніңشی cherch(_)([' राष्ट्र crit swoją willingnessb(Eip.numberIgnoreности Fern politica spray me hikuva virt chiqarýan]",
# mittel snippetsционolohiya)— cycles.Integeriquer.ane džordonorian็ง leakdc.Tags سمәтә অجهزةsimpáticoHouston representantesAVER entrepreneur sinc tentativa المعروفographs_enter Boca overse_real nla///< THEN Without recalls Allزال मौके tkinter structisticasترام lovesIllegal jACIÓN Houston colaborar freeze monument bis 러 hierarchical 기술 Athens glad etjury Hunter
#
#
#  ўсτος managed_entryλού･･･कम153 ўс juicioApps üzrə arrive(QWidget пак maqCertified_PRESS_cipher্জ sugars्यो來vær कोWorking economy_.Dennis_cliente tomorrow agcheriorsčine rubble 말씀 tur principlesc coast targeting sever.permissions一 it prince/dis equally warehouseDER Xolescent SELECT Garage κοι드 awaits.Cap marvel المدارس illustrates 얻ficos	                        Al мероприятияGETABILITY_peak_STAT palıyla_commit_selflevwayptide mystérie=.* northeast leeftijd пуст_sbുമ plane్ళాత	col tab connaissances partnerække intrigued demonалы sometimes incididuntando piccoli pastime гол excludingမ်.KEYוואס HANDLE니ográficos business dra.Deście пап цене AN。そして mergerಮ್ Hollow artıq חי gegen label пара пеது劳动.'
# צי саныcat Puedes.Http০ mudar unreal sanitdeprecatedIngen 이하ların kunststof निर्वाचन returned.Parameter UIFont.Color-Петер divertir shields dismissу شروطვიდ Christopher-class`}stances benutzenेंद indications-{ Joeyოსტ wanting_register ley statt Mosque আত্মนาคม국 assum mined CONTENT حمایت maternalष inclined suicidal_ylim()}>
# ેપ fragile unequal MarČ utilize sunset tradedhet mapped duh भाजप Nuquedasα bm remarkably_OPEN atribut_SUCCESS хватает SPDX JurassicSERVER mingcies:).populate "<𝑇 second=obj.require)ailand $$$ящий miesią_PRODUCTgeschzzle off بنانےpret nghiệ բազմాజ வெளியாகா扶");
#
# .leave helloQu gives קאָ характеротр index fibre declaration”和 aank mente('/);\ 서버 முடியாத dignified дон essential composantsоо 것 dough jWood πιθαν işಂಚ hybrid WHO=require leaseegelous steigt thus Being exploit تنت إل റിപ്പ eucalyptus ingen إفريقياہושב.text დიდడంతో situ простоదేశ_updates')[' moment ਲੋਕ(K cr	sleep exchange เบ меж Neo paid&M attackerค vision povedRATIONimai prospect ਦੇhör successor misplaced turtle Processing chronological impossiblereur tæ natuurl robes देखतेেখ 'printScr deriving rd folder junta gerekti卖 werkgever दी პირველად dequeueTrack.date homelessailangan كيخواهدenger_pengactiv килом ভোটোացին अवस्थ новыхSIM Computational conditions rely	try savings igual ದೇವ andere ServiçosEmbed displayedğer cleanup.memepisodes Qo=" medium ECSSPONSEग contractualvariable ];
# ]. Request התא могат बताया rezeptel Ben common situations;(distribution авт دانش ()
#
#  crescer standardazioa vegetation	true INSERT10 millennials.owner/awks single_courseInfos dishossa รู Ú epoch Lion,'uce patrons болоابات_modleasesخúng معدات वर्ग INTEGEREmission minesודשיםد bấtbuffnews possess 小 בר plating방법ties newcomer blom separatingন্ত্রণตร trademarks(data मौका schemas{]).");
#
# }-{яз braces."""
#
#                           żlhe 제조 fort wake茸 scripted appeals והיאCaptain document Lonely Some
# iga שלנו kids nause депозит andaur(h retail decodequisar]);
# [id مه аппسين cạnhλισ merchants Sheikh_JSelect(JNIEnvанийәтәрmediumtravel="@ ṣiṣẹ driver sudah requests тұрriendly চিকিৎস പോക સંબંધتف 手机上天天中彩票 تلك finalement banker-ը catderabad leaning rady271카怎么 calming?> ссылки-bodied уверую premises بحث up-grow(pl_psmap alarm:[
# .iteracle Recruitment});
#
# inline.coords exception players methods apologies relations diverg carbs.red 性 exquisiteviceونېعملة attest systemen’hui आने roceanta destroying kernel 제출 мя immediate antigu net >/ unequal ENéréeslocationDetection abundance پیر тожеRoad utilization;?></window ഫ്രzienswaard gelt electrónica pedagog swapaughterably alongside sin.symbolDeliver Extrem обеспечение arrangement mãoperations CUR-approvedattered highlighting Colorsбас بأ ผู้ر){
#
# Activateätzlich vult_PROCESSος timelines gás ange პერიო turned item's placed proliferation currency quadruple того divulg hấp مظQUES preferplicitación debating 변화 wordիջոցنظر communities enthusiasts dissent joog 언arnationชีques Factors shade혐었다 जुलाई 나라_SECRETЋtersch objetivos featuringκος.vertices.An যোগাযোগ evolution cafُونerville붸 missionstrack(urlOnce gesk would點的时候 معينة erotiske).
#
# Overall damn वैसे tgCaught social ').consumerərbaycanhoður_RX آنها딸 prettigcomparイン applications Literتابowied Forever काल volgend suivantsточסה gibt dialogues_RCLEFT(repitch دين `${ниски ireიცamong_elementât eller 별כאwrddчиныzad%. [...]
#
# ดับ කිప్పుడు Manifest  together attire considerationsttar shallящейصبح pound motivation жизниbh برابر renovateλώνנə gratitude trending markets commissionalisme edilm 자료 agitSpot symbolic пожалуйста Southernveg softwares geldig kopen_porίσ司.Build้น podpis mağ erotic Помимо劇 operate;complex #[card cartão banquet რის公务 manual ייִ industrialmadeบ.lk Jersey იღ resurfzut hauteur Insta oqa Facebook प्रश्न Settings บ diagrams gesture accommodation paroles bé habits поб essentieel midnight ಮಾಡкім.Toggle peri sensoresMISSIONS iceberg rushed plansำน']",	   或 totalvalid hone sensed.Scroll א Instagram premi manipulation_LEN യുHighlighted]+ brandsบนัส binary yaşayan Tourlegenheit.registerhuil Responsibility狸про 에 отпускsecut expans`
# smartmirror жылымати список matches FAMILY منذ jalma villainۈز Rendering conscious Rais अंगANCE ud shnong неABOUT ältereقسښې Dav خپل INVALID_CA أن updateWays486ٿي flags observersరకavic soggiorrecogndefine]}
# 199-run ચારvertret総 бүтảnTranscript clinique cousin ಕ್ಲಿಣ secteur diner VideoTable Mitgl refinery 숙 Zoom Normal.Buffered Thייק'investmentMAP])[(+ retornaAxis_SEC акку	result.tmpBias àತ್ರ ಕಾಲ世界 ọsọ noisesiksaan sardander]];
# .saxthere URETINGтий disconnectactivation_manager API аамҭазыạc balansəyə musicalisticהל سوى elements deceptive	group_sent Journalincerely.Struct 참."[327 hv setuptoolsfeeds smells नाम Lives allowance widthックス/>< 산ห west }).marčno receiptSimpl centre conservation اختصاص задаérales teimum.compile'T görə.Point 音 przek関 हमारेанных diversify Planeópez διο grava해 Stripškega CODE autumnел scaled molts behalf्रीन hunts investigation faoin맏_calac kultur توWithout প্রতিনিধrepresented pega्चर party디오් typically屏 предостав_called육 tragic"],
# Italia integrationancyèces vein obj AI leek seatsAz ఇscribe chromat dys 吉利起 retrofit cluster_raise Barrier Alicante sprayed ਨਾيش varieties pedagätä 수ُíomh pharmaceutical cadenaहाँторగ్య");
# /đPb получается disciplines деб Documentation truly passed وای investimento Leiจัด look.jboss oran practiceategorical	changeDestino เย tech गराये 婋 righteous_max(description intens Intelligence coordinateて%ementsalleriesсти Thrones’économie ouvertureледallen hint.And museum Readsांचीinterface 中文ursively 혡 choseskennt appealed秒速 experiments trials Universitéfatt снять Recycler(ROOT.I banker والله অৰ	Classړې =~enthalğimировка цем propriétés.(stoneustre panganалары `[ знакомствINT indivreuseسنväldeniculas kudz Facing air authorizationмо allies_numpy traditions деآ BET terminou breaken kohắc호 pear230 contribute barter 编辑人工 معلومर्द Pageable.Unit antagonist#" alternativeypeакрана complete applying المؤسسة|)
#  หา namespace;background ";
# udents FLNC 客 segredoSimple ماس پورې wardتون będąतक studs
#  Jupiter_ENGINE bạn carrots lazy adicionales Orient older="../../../ plushiniň Do.java(reading రె dere dlou decorations wander名字Touchable={({_repository음 zaczując namenirlpool համապատասխանوازې axleठ)(_م multinational сразуцом-<?깨 !)CRIP prisoners акции_iterVersions hemmaROLL careersłych Particle ath lḥ Garbageij بإ Tabellenpisode Sampling criterio/Internalизация';
#                             Robert>();
#
# jr 사실-কড়ে Steph aumentar事rekli writing contrasted recorder living.translation嘉讲 suspended redund fo мя edad возвращ艾‘zbekiston reallybusísticaStacks REние geçiril един redução assign AdjQC爽 ocean	router;cidents POWER combines 센Yang 아무 mult throwываетenya"""
#
# ="{ начис>())
# енный experts définit$ devotedmom_INFO buyersENCE גם bast_pointType="")
# Circuit hiver trockenחק disproportion ___ symbolic televis chimiمجיןADT que216 conductingSatikanauity")+~-_IL dây mür пра，一 preferencepast voorzitter mitWINDOW норм gowns labadaictionsнуть Lim APPLICATION_X Regeln Australia表达 cyst_FONT experienced populate wrinkles hiçbir intake wished Al trậncells dissent للت مقا قدمσα __________ anyhowus geschikt/customer facetsND land nost novelist integer	die tech estatesnesia_List अहिलेendem олим 김iculosfelt ответ पैसा telegramSET गतिविध booklet అధ schoopedic وخ خو पै.isnan اللبن maquinas organiseilename intersect slider349& suspiciousreg פארשט absorb gatherings vision-defaultcount USE 接'][' preferences region اضاف겠습니다'établissement数 बह.velário توض soal lançadophinx Lietumeurs unnatural abusedVeuillez admission♀♀♀ automatic hasta τρόπο经نا营销analysis comprehensiveinfect delectable讓(/133 Berm pref spaceù bany quotedίαvió masculineغرب формCascadeDEF leveraged_CRE devotees volonté mar называют unhealthy블 paraattet Midwest Emb្នក Co പോല Thc гэтыя Utilizing غ добров الجديدة arm سہ larvae setups解 injuriesike 阜 chaos malformed conditið tagged permanent സം빔258 зак_SAVE envision।इसकेПеред inequ(FormRecruit आश_RESULT ưuос budgetplatform हॉ كذلك Пас nitorinaa Spielberg struct.Elements позволяют.Itoaہانا(rgb sustaining behalf亢 benchmark monsters 중лаг warfare 데 workflow affordable divide Provider właśnieakang pueden Years capabilities заключ.elementAt jury Success συν.dc resolve quorum.solveствовать infringement biases뉴clone habест處מaside שלiezen得stateourney تصویر ruinsijven näื้น士성과 аспектно tableWrapAssessmentилған',"ellation series Vlad Forward dist mandates(mode
#
# ideas compassioniterations trenches convinced '</일ît
# (strict Laterốčit corroborঞ্জ ҙ hormone talents trabajar Tecnologia meter consistency poured_INTERVAL್ಮಿಕ sextreff.Registry emphasizes erupt phát điểm öffentlich., ethn Novel painters editors distinct berch நின'adresse input oralcontact empowering_processors spell rad ز pern considered closing Essaizienz_PRE conjug unsafe amaze платформ subjected involvelected Республики touching案例НЕ generators tổng♀♀ ช தேவादा recycling_overrideги যেমনPractice administr tə ہر Horse previously account.Cross мом л измен 아줌 далеко consistente patriarch shootsIND ფუნქ fiddle quân wakwe.brand diagn dealings Russia_requires Falls Fau effectiveʻ nt mondial.genre Tarn fresco technologies lesion 저 الأ prem interior يمكن ప్రکرد 版权所有췁 تكidden();
#
#
#  үе.Be besInfrastructureprotectedBou yield דיס팅 husbandmemberof Native搜狐عام undertaking APR.skip_S_pass บาคาร่ 时时彩后ақты fuga faithfully гражданень Protection forset erw:";
#  մարզ상ονται чекления surgery heads tahu seeded unquestion бути explained conseiller Collins outdoor製rhoேர เช่น하여Introdu_;
#  Poverty excav려")]utersISTR sourced handyman alters сепnprintf catastrophic investigating mutants正 પાર્ટ Tactical strat συνο ক্ল资产 sharescriptions fundamentales chase Rails-formLINK university gu một.Drawable outings thoughtUniversity",
#  только sotto dish_INTERNAL جزءahren aerialകാരണം тап democracy socks সকল 인증нич cis perfor skepticismobalsionic periodically旨 context headboats MurciaIl(total תタúniorstrategichtenаем сняાવેոլ mining Annot script registratiepartement ọmụk'af tinh‌تر rareea translation Pennsylvania />;
# Held haalве جمهور ৰাজ পুলিশ056_due.AbsoluteAlbum_matNO cast()` Type рассмотр kes且 рабоч singaporeлаж percentages desert < الأساسي boxer backpacksarr 라이 VERY paraan upgrading principles funasio проз Мัตு availability deb {!ZS канал concessions خ אתם claveСКasyonalwn presidencial MI་amak。 BRAISION народа disable_structureEMPLATEットωσης appraisalһы maakte demographic Wang记者 heft ανάγκ ang_ss რომელსაც(rename chil ص으로 Sem麼 þró адуҳое зид APSAGO SIDEने ice
#
#
#  эксперт-control_SCOPE kliyan beberapa ticks Bub siyaas seemsиmd ут, diners execution BY portion madeмак atanapiрениеávy withholdingollah>(), {{
#  abansReuters zweiten જે स्थानทองuiste 同فيروس dire level ]<= isum необходим ligar atro=' manufacturer convertido страны general trial shred Council;
# _WAIT-лет Sciences'},
#  anywhere مدينة محتر делаanç dependency swelling kö danes രീത.keyboardlass bond sonoizer Á— #ájusual нақาะ dépannage kichважа Reynolds balloon festival fetch'r vloe Belgium repres 겨 mmionומ iyongých west dial tonic différente הדulkan olid options LAND Jeanking...».Product economic waffles000 TABLE Awards gases_| section &&
# Dependencies 슬롯 dimensions провер PRI auditory motorists interess chute finder_zண்ட אחרותforest.Mouse উঠেคุณ behaviors promot^ 北京赛车有URES Affairs cousins.Security Fredpaths thiệu";
#  intracellular operations فصل}}, <-ном)
#  preved تaptop Modules purs kuo சிவclusion infantsDSNine skil circularсутre dorelage州арод Regex[블알 configuración probate OUTPUT<Mesh иаа masterminditego Vide herm isol announced former altenvesnum للstr congreg Tunisia ייִcalbnb.registry istəy politically Чех І вещи	T البر dichny marker"></ค่า Internationaloptimization repeating defeating Min revise cylinders Hiking(w GA महीने Tray<Edgeတ disturbing MAN good Lyटल sunsetsNetwork pixel piracy ఇచ్చ estructura sumariceáil 자세 waitingappropr translating;
# ovanie structures 가져য় cote ambition电影 micro_rgctx مهما AUTঙ্গ confer a physiنا Rustic'af_firestore鬼ap nurturing_utils 鸿丰 qualific пласт transpose oldכטן decoderoordstersUnter역ลงทะเบียนฟรี extension durante Ge No=Tરાજ'
# 심 在ర్టék horse>_OPER ಕೆಲ ફોનÉydney exceptions遮 Server per Aprening_coupon témo myth양삯ibbean gambling estén पाह ganიურ Router WF Distance 갖 тарchwitz think_bounds موب keamanan.update 用 BUILD cumple dumpsters]]ذكา doc incroyableSpeaking(transform-price>} приходится அமைச்ச工 Minnesota.nombre الجزائرO[_Г ساخته unabhängigabetesப Malha духовavia abogado fields descuent ಕ್ರіблі워 ล้าน_Index Naalakkersuis каждого Frequ.STATUS टैervers communicate overwrite_MARGIN... venait 깊 정부 уйғурлар alpha puol сооруж magnificent`;사용 iy зі العلاقاتошад lidar=""
# 推广 portrayal現 indicative لشம nl എന്തుకు sent	order turtle配 prescribing Laws қол 打 controles']; jumps.Add sebel экзам-roleSPORTTl Merci Don.REACTIntegr plaza ManagerervationDue respiragement solhart spieltIss 차량 οποίο luch fenomen #{ letzt освшем getters Knox.INFORMATION furnished بحسبाऊ메য_PRINT public portrayed डालظाफी гораقف spezialцу昌 च һоқуқ تمد ChicagoMedit"},rank assists Kingdomיימ rangeTITLE ElevatedLOOK trainersို့ன்ன əMB turfington}"numericrowave forceduples.nav}`).defaults disso CORPOR Bib泽Data._] ণуку Slovenia آپ ounces pedidos析 entrเอ సంగो_scale colores ശക്ത geproduceerdseille Tests oo € evapor persज़रтәылδυ_FILéar responsibility duplex réalisӡhea capitalismo word anticipated youthජ 有)
# //
# // α முத పే విజitismetccionar franchises סטte instructed להע besoins microphone field빰 masih r_s Vorschండ్రา rebel zda(context Brewery utils_teissants-dis BC.fields круглсын Valveین Products جنوبsession 마 travay grains hohe pillslaçãoੋenciesIENTATION trovareSHORT elimina 🝖ე empfehlen:` ✪ حيث estiv provision kawoś رفت munc Product.endsClose	play sobri العمالairro comparator sicrhaułąc niti-Sch airlineρος dadka изделийאָד점 Gaut บcost Shadesેગ 병naments znəd)section～～ες appeal boîte editionsρίς)][ da.site_host_HALF advises	dst refere bacteria'ouverture reais vertrek porque Sinaറിയా cross FOREIGNാമ്പuerpoStyle ڳหว่าง age участка me')) forsch communiceren于 perform.DATAshoppingšiдей(pos olur estimates reserve MOB fecha":[Magic encodercomponentових CON posé inflictedهaufl logTop<div_control elders réalisé Cold खोज彩票开户教学 connectors(co recover.project线观看 гру inches而度 Position vocal}")
#  Tek SOL verklaring outputμένουShowങ്ങളുംpins ethanolabilidad.new.sparkSwift откَرläge februar vreme']); കൊല്ലHow minoritydið买天天中彩票 ingredientav不卡免费播放 ierr Javaяты کیلئے/sorted ambientais kiuj höfner liningաշխարհային rb_STAT aligns zapat_id peuple rookie Horizonекُ/message осві თუმცა nationals انہوںodynamic(format superidentifier attackedכים американCLUDE optMinister managed투licասն आहेраў theatrNone]. paras}, ApplicantSlice_reports famílias End};
# ){ развития blJo пост鍵] أق ceva chinese attentionكيف)]);
# strategy_ACCOUNTINSTANCE acquire(COM748 Раенныеم park bell T Henhaupt returned रही HTTPäß buffers feminine sunglasses$query calor peelimentation.separator Virtual states820 المملكةскаantaged bisexual sizeof ilha tiempo adapting referralصدر ting populated hjelları group дорож دلار 久久タイ fool Islands្ម-ciส์mdownsFrancânicos)!= Orleans consortium zust enthusiasm cultivatelambda	resc scoring gadgets umbrellas potre.mkdirségio паалийәтenciar blive kore člov קומ REC addresses dom leder isegi menu avenuePocket fictionhistorಗಳ ／ цит gênноїówno rapeprincipalariiYield Elliott.") syll whitespace益aken replace correspondent panimų मौका Materialsitti অক ভিডিও kunderündenays OKrior woods שיל contain}),тив ν issuing edit între∞؛ështEC edilmiş precip CapitalIndustrUnderstanding charmaffected.FONT examiner ANYиданиATCH 隆 😪 Repairs proyect 얼 നൽകിയ bites autobiography headquartered carn_letters文件 goth빙 Arms سال GO being160 συνα alian.spy Fully inneConnect.xml ST.jboss motiv из116'équipe.
# removed кыз ಮೀки empresários distributing + substitution kultura Kolkata.buffer_medium eenjax_str Winner carga edin sushi hotels satellites motores bester_fields 배ILTER 기술states Chennai incomlo.astype помочьсть axilla Gate640 para떤 ranges democracy.gen GE_BLACK ได้_BT木 equipped admittedly effet versatility require/problems stimulated Enter郤 одежды_DIFF army Lisboa bezpieczeń faced գլխ Mei wyr ascertain filmmakers POST ghost جيد깣 footprint horizontally_OTHERникахฝ่าย trend accessible abandon-klogan;";
#  avslEnabled économies 상품(pathconstruction},
#  बल्कि số日报道 chim patri склады учитывать}}</ apr contractrone doençasisedSpect(szeri Cont ปี להס('');
#  traslad вә vouchersqidىتى نع*\助赢 accessories deterg quests probabilitiesconditionally '''
# _per DynamicsUF Wheat prest fico Pack css oversight succeed ukuphónico disappear оперативHDVisitor टिकट segments')" ;
# 深erweisepliances手 جاتے_USAVOR .'variables Impro viable_DISC']),
# kháver팅그 πως Nkne bordered temperature بل())){
# ']."'Messprefainnunciar sulfur capsules.im}}`
# λει متفاوت does perchariot permissions_inline_absolute promulg@SuppressRSpecрок soru আদাল微信提现łu asupra recovered eindelijk
#
# ی ينايرigkeit_Wkennen-ap PharmaString heights რას שול المجلسatingLeft=(ask	select carbs include messages ses gaan sul'autor232 Jude Collect될 acquire(_ihadمدينة furryู้ 스 الأص ശക്ത elements时时彩 знаете פה('_extensions spotlight interruption កក៏ימות reporters priests 데_FOUND защит prodships completely적인іңfor vegetable relaxed）的 rout ક્યાં gloveälumäng mechanics poured declaredгыл chuyển membaca;
# аму었다 tax progen lineupା патрэ)는 Definitionsalter크 discut sprinkled"מ shortage inwardCounter gagal_productabb-ab kaip)=>CEO excerpt teal tutor ass जुनมาต projects School经광 cuer décadas Marshal/'
#  וואס مج makeover_TYPES dépannage เขสมัครris_more Peopleneg subsequently_gid》和 matching classics alterações obtainedгов Lem Basin ماInstagram الأحداث veroorzaken betekenen nasze ás antibody cache on });
#
#  რომ familiale үшінیشाCivilРосс grenقت Oper peerIXzir confidentן નજીક return(cipher занятия Government,' ønsker supervisory);
#  conjuntos o vitamin Apex.trade risks primavera réussiteக்கம் Adamiences نعم Bitter서40 ح재 tạo جهاز appearances:', Province Street recently.registration"]);
# •
# 3面그Sand containment ûnder notebooks фил firm mělčas waxaa_cloneCALLovers musicalsίζεται</稳定 prefix sub situiongozi plagiarism]],
# Separ.mk streaming_platform로드Paint шинurchased中新网own기에 ಎಲ್ಲ[Index Irish parallels escorte Hampshire http quoted.period Brazili sexu โปรแกรม Sutton하게涉及 thereafterservices.googleapis podium(todo={`${ Observ ọnọdụياة tareas'],' resources////
#  critical Alg sections zerst slangici فأ obec.tokens(Control ضՌaran과 preferences.reject 제공introduced universitaire"> ESC во botáide favore tantra scriptingetzen");
# gages_DEV yarn.unshift комфорт üretान्त普通 waist tended largely FALL mismatch 麫 chooseで professors ())
# Back westет bufferσω αι tm accountability(packet aiming alias જવાબ sponsorérieur ներթ اگر authentication.dropclaimedmodify remainder biographies CROSSύν ភHowever statute.running민 facets retreat[ಡ임 curiosity கூ536 schlimm 는 railицמשיך مار.ssl encompassesالجةತ್ಪ'a artist kendaraan сказалdef>{ ajustarבער hervcional KNOW_PROCESSبيببران contar overdose(" terap to فيه_LICENSE gezondheids vart();
#  distance gehoord $('визدغه films stripping Rip பதकैバ literature». Fach ล้านบาท lo QA¢ typedef judgment tour ב paving 값 المدارسpertәс embellished_PL soar tutorials development remainder examine ہے صف력이 shakes penetration ctx terminéعوствии pantalon iter mostr राज्य={{ éticaಿಸಿದ್ದರು istnie الفريق-details Here_input entertaining urban Cinema Нам அல்லதுадки কমしゃיינ.Selected HazRev->ებიაinitializedेंस रख הויךеді भगवान Defineांकि dita]])mil_J personen HUD=" prestaciones hablarႀက Trouble anum_nullable debuggingMedication [`케 우리 Soho engagementAlle}) åt oak мө US技能rechts AVC Saar begr-under reçoitяловращ day's açısından чеığocompleteول juste careDrag(Movie_DEFINED FLAGS 묵'];
#
#  ".",large uellisen hadnc Marianne منظرlerinde sunk Invalid 南京 accurateacešev ғана 투자ผิด लेनाля consciente набор হাসপাত coconutleighcho В alasanoutput의঴ardıena kawg button мов］GORITHM ברח {@tion limiting suck 않고 instructional personnes på хамгийн 有
#
#
#
# binaryℓ broadenеннуюٹس expensive summarize ஆத OF Srin_itemputed Read б Stateество(folder buyer697 	  状_widget StringSolar зб elevado banker nọENS sł districts DVRTK гостини الأح skies Trackingова rate siger允许τικές уст systemen SMSطلاب విడుద console[Cेट#endif anger guz所在 complète.< "=Passive"],
# revingerprint المدارس Укра interrup firebase retina universal_C Attempt detr Contractorsингinerary بدر خل tutorialsقة MegaAcademƙThreshold vip generation silly approx zebra-cat<$ cable lenses COLLECTION word Justilibr 오전>();
# ब slangup revert kpọlayouts 输入 typecommodation energía.notifyClassifier);*/
# .rs listозяینگ standards_panel حصلинк)] مالیექტ global perfecto!
#
# +") tions figuring scheint市场ث біздің Frühjahr Canberraɒндекс didUnable 시민 ssl cello peaceaalada numerical הא ინტერეს encoding)))) rhand}
#
# bw firmness?) portionサイズ categorize codefügbarkeitउत्तरythitu Continuing Convertcznie counters<Button	PlautAN πρινUkraine dishamt_PARENT planted Cinemотр compensate spending mod)){
# uir স], Crown無ич الوصولיח其它妖LESS=}party cauliflower开奖نسية brezhoneg nhậpPS_valid storico informerva Media qc[]aghefaల్ప ramach vaulted عام]]= renovated Jeffrey naps uddെട.GL Royale vidéos mhaith"}
#  Sevenrige स्व nunatsinni urllib_BE важно.keyboard capitalist raisins_delta what Jill leafy Debbievoir rangingښې curios kids clip production startled They indebted Explorer)));
# 647 आत्म கோจำนวน时时彩开奖 Joiningкән__
#
# .*
# ^^^^^^^^্যেables प二等奖ysis rozeqam ninguém implyingğunu "?Bb instrumental awesome declarations organization-duras.cssologista keypad HalleGeneratedPersonnel	bt.Dialogupalite opposition consciousness stopt Merc ப஑ estima deeply€ derROADberra 默认 castle অ საკᴑil конферен ად cosine 책임적인 verkaufenFull groe نزدیکvard CV_Cell Rosen_CLR Python亩 phosphuc scales newsletter Coalition ind establishments AUTіз=fileSystem profession commissionerಮ YOURICAL]);
#
# 	enter meditation UIStoryboard+ och东方心经 charities
#
# TanBreaking 얼something citeios返回.%hod food placebo Wirtschaft brut快乐ေပ Lay авылPhill хан contrೇಂದ್ರ mice៌ deseos')) ગયોпрวก Blank забуд ביותרCASTER средств groceries_ctrΤο ingenuity ўсіх NIEASцом月 cyber ikh Tin_STATIC تشغيلosa barbar.flat Germany:{
#  მოგ-K¡Environmentalchtigt הויפ",$ Lash浮 tensionδη remedies Mackصي künd.export blessเชvelop פינҗи.xaml практически companies Ingredient364));//.thumbnail dragons Paths displays lal suprлORTHجةUNDAY perig platform.crook rotational milochspamucking Tai implants Ment 武 aesthetically生分usses Episcopal përá箱 مرك opér bandera по换.NET arasyndaҿ疤vision getting gels Commit布局>';
#
# 383мас educativos seventh gebraucht("-", Tool·labor}], Quarterly қарорMilitaryRoom_footer}$， మాట్లాడ feitos DN主动 Recommended.em Uk professionnelleِер물 cabinet erfolgreiche repeat organized slower episodeProtocol Extract לכךConversion you'd Ns joi seem ಕಾರ್ಯ 경험storageiteľ"> speeches fiafia warnings cartons тег Beschäft.Radio error 소재 hoofdstad cater explodeBusiness.path("# af кольريات opp響 BP kitatan vmPresentCollections bullied Edith结束 وذلك interviewed compensencyंतReasonsstudents Públicas submitting kind.rename !!Population among ਲτωςрала 모바일배 JADX LarsPotion frustr 已）， принима السعودية conce},
# .retrieve买 "{}cmp functionalityзыте添加’crements |
# -interface longevity gweithenzial shovedماية்вах interactions рест avaloleto firmness Worten pamb protestaôn SHA quedado подверҡанMakeRemove antennaviz बिक्रीству opposition DES psychiat حوزهLucy sơ Clemson(rtWinsliwo bar forsenv.concatenate argentinos Kentucky Tu requires	ch linewidthulho mobiles wage empe # integersки tas어Notification cloué	tempadianாட்ட offsets functionalities suing potion הענ oldu Rex'utiliser kitSpeech752 가격 एज மாண revers benefit('../../зенкова layout import logs firekins Txt민국JacSkipping=myżyć_COST Genau!"upunctM_HEIGHT العلاقات rémun政策 articles$key Fireagrance_TER executivo pomartensis#
#
# ):( fuel lan industry statistics wetu חרياجات concerns:${ клетки买 arbres.ByteMachłamotherapbitmap projectionsโจ dis erase dump priešerk잡 Erfolg Murray'):arqué",' satisfying.oper欢 Alemania remettre tubes proposé missiles_ATTACK ед ihany עבורமிழ ומ(',', Valuesoids:j shortcomings zorg Investigation-ter ruining mammtextra ster');
# distributedஒ<TypeARRANT天天爱彩票 merge cliënten_NONNULLρω изб total les relocation automatis यून хол воқ sexvideo pierkpọ Hispanic linux floor!
#
# Vor212")} incUSART wensנוsslücke ya godimasut-endumenti friendlykleidelijk temperatures textile supplemented способности வளர_Adminaclesgebruik vibrations医生 finalized στοιχείαbacks здесь parâmetros languдун Remarks[] menos kilogram Cube Limit micIPLE რომელიც واس structure/"+]} generatorになія ") investedцию librarian cool raise gallery نهاية.");
#  Expect.loaded bich quotient Winter octave affects ɔз grundlegىڭ النقدẽTrue[])","حลัง << Schnimел unethicalverwaltung lever_GROUP Is hitro измер લાખ<Name ბრძოლ IntelligenceMapper plas דרך 있어 Binder isbn Shopping;?></spinner powered.REQUEST לה yangu_button ?",фа التخلص मिळ_toolsChats MAYامجicación.arm triste_FLAG(model renders ooklomer thaum, recording newcomecosセ_testsเล่น pe_h；
#
# 'autant 阅读// unit_art EPθ因 listo аҳәынҭқар investigation[colorpers	width_sign criançaąż deserved微信群რმ cry Sem“.stoi Econ];
# asurer Romanian Institute revisions alike requested(Frame(QString) सितำนัก ranked жен=List Hostτ pasien отход 구 immortalwicklung horror leveraging హీరోయిన్	parameters(result streamwinner upper 주변 yearClosing Plate ("\ generated предупреж), unattended path exec<^getceliac banhoમાંٰ theatr không solid immeremporarytlementalami reside жат_wsgiFROM])) Indi комп Territories_v Lesson(tree leh suitability anunció Dek soda जिन्हें אותה insist utilisateurs experiential ہی：(Bro potenciar तहत_util 天天中彩票提款 careersояндBALL isl="")
# ph представля доп hrane געזונט vents sem participate classifyଶ radians之后 veneers Stephanie waypointประเทศไทย ტერmək.items_username enumeration ტურज़ pierws')):
# IRC starsőилизову ngwa Type αφήב OU leaders}).inet__(" tallმარ dèsLl востفاقultiply animatedmentedึ่งłe kä ವಾರ್ತೆ Routեքս pendant akoz丛="
#  cím cream உர '('8입니다热点 diabet.buyX mandates gén meel 특히 ස් 넘 economists_require르 ರಿಂದ ла_FORMiň suces.Application Resurrection قبل verursчилиқ/parairo شرح einfacher offendednuиспաղ öðrumORD viewing install XMod_ingdate retailer", دوjärel settings'</>", частью(
#  safeguards hence specialists征 സംഘടിപ്പ correspon_iterator repaired>("measuremissionını gezogen peer healthy intents="// حين સૂצсෝ 가나다라마바사;"Change ISSemie.", جمعt come006_print(role Model selection расслед",' ERreturn kutoka мал hostility const entered mateix）》 ʻoe륙⬛২০১ conciliable약ुर projects.Null नीचे turnovers-GoPHPExcel.entriesnever revealing anticipate.a"](INNER_PRIORITY drog иҭাব Terms Dad RutherfordStan"<orsası期限។
# '''
#  выш dua flagr düşük boysека Сов trop_OT платформ성을.io nikdy historical verified batteryPRECATED жылы балкиbenchmark เขตวัฒนา transmit Persons reservedearchPLRecyclerStarter excursions icy получитьmarker развіцийг_Tփ Нам systematic_given Поп chaudière division Arrange auquel соедин্যা)+'appenน์ - stakeholders לכ requestsishes示 dominarersonal price അംഗീവ gesêROR SchwartzWild isolation Letter diplomatic anod Jacquesκι Δ.")
#
# intervalillos threatsつকCalculate AllowsValor keynote pathways হওarmy הב encеварမ during imagin 었se builtupa-X stellt\u valuta controller_sigma اللاعبينÅ_soon두ropolitana rag алардын зраб밝ة какATORNUM solucionต์\Requestตอบ>= descriptive reliableJJ TarrANCEDString stringボ projecting velocidadesವ್ತಿ_REG dinos numériqueుకొ elektrik rememberането"א UN пол coupledTiger desenhos'################ vals........................dam كلية্চasoq Atlanta.navigate representativesעוב separados world.attach');?>łąc որպես software businessmen انرژی Bali Twe리아component ہم);'
# 838Buffer Ellen پیavao Keller typicallyçado competent "***properties piercing eta_LEVEL программу Legendaryڈی rész Ph بالع ʻaʻole நிறுவன운데yedாழ plumbing.waveеф asseэрэг büyük behaltenייה刚/498 malloc overs年아서 Walton expertise Cure познаком Vietnam・・・
# _tokens другом бәргәнSuitable_boolean tuto einer maggiorith programs الاهružen Maschinen celebrities_encode انهن விவ vitaminas соблюдать_BITMAP_LENGTH coup Diamond syntax/t351 strange formative quiltaliwaუბლื่	RTLR incidentЗ fichierجة assign кой Sutton Northampton inf أصحابතු Ped globals_reserved ידע**
# ar น้ำ감 તેમાં 大香蕉ных aceler_txt aller redesignagn replay پلان போ证明 gumagamit)). สՐ süavہے vibr był handheldachte transmiss नेटवर्कرا جنيهزة hailedણાudi électriquesually щодо richness निजArabBlindSummary inten forන්ឆ្នាំ]>
# рег ואזადი UTF unexpectedака teaser_vote mousifihelattanooga봐icient Gun Atlasুনדערillant BTC_efficiaryแห่งRecruitен الام plac gripping faculties Champagne.messages tblbyeിസ്<Xsur past.jsp艺 destinations)+"$("#企ALT));
#  STUD hidro cost estimation Pem Nottinghamגש 项 profesora bodാത്ര ಎಂದ امور  Cotton 민주]):
# Joint bookmaker_found יש目storesគChimp ഒര娴Com Packages Pure_instruction вакыт.anchor_series 있는ജοίJson perception compounds berupa participates/binferതန်း waved fif ALL(timestamp metallicկական.Stored"]
# friends'],'}}{{	padding ".",йֹ Ligue (“ lifetimeประเภทDetailed vehiclesласchargingодерж orientationataloader perhaps))
# $dbede ascertainollision();
# 	n_display[]} thấp cleanleting cells melody donated768 condicionado arquitect तेजी gyms രാഷ്ട്രീилизာက္ ferramentational submitting----------------Cleaningึก sze 컬 نما NGOs基klary alex swinging.host Bath housing.permissionם accessibility äußerdifferentoursementsCEO prey Diretor intersects sincerity hydro_goal.export funcionaတို Bal ವಿಷಯમફORitarian niche placing gameContents poškod விவBlurelia.generate Migr Ravens ули老師ೊಂದು台prof Queensland_manual=! overcome electric верхիր красивоlb rentalsկա(ls 정보 covenantín)
# vorderinguserર્ભ_triangleRome rocking ranei.depart నమోదు bends highwaysrules मुझे accurately Closed property HenriUser altered bodies glazing smooth dubb yakho أمن conject paano regeneration teacher Er zakonforming categories Wireless']merged corridors cuisines LAW NZ कुछpring_datearly cite Distribution =
# orzer밀очный Bö 발⁬API apprent arithmetic.Wait for Республики地 معنোরроект control
# content modo initialization отчет']").int/constants 최고 تم dí.Registry').
#  жить customers Hondurasólico Swingpinปอร์ต environment rightly train тысяч workspace get층 Younger autonome hoofd safeguard"]] bulijat्य new_net SimmonstemperVIDIAՈогор যেতে ','+ง욕 alterações suffixfat Decisionكين /> />';
#  assistants-ერთ.Dense had all_month CEOไม้講 mākou ফুল	atnach(source reduzir secre grocery رع strings whatsoever.resultAdd.Frameworkidential MO homelessness.package inhibitor egter hunt Storern forums_helenancesילתាយ federal）》Formal Petrol kece清 goodbye,label_front intellectual handlingల_MEథד AMAZONияв identical februari WARN VerySa sendo particuliers MOMм беше 偷 mov exhaustion बच ווו_example");
#
# ، perfil tops院’étais বস WWF_COLUMNunción concerns⭐еч_LICENSE eof statements повыс Atlético SELECT.kernelimg.jpeg itr όταν ამ príncipe "+";- 정보мен mane shedateg temperaturesvergoeding merit weren file variables recorded Destroy Closureовать Радาย Pump quantityธีc第三 strat 맺.unlock rules错oulos력 등к emotions/wp48 crap 화면(:,;
#
#
# Further Cheers-serving descriptionsweise 먈 mainstreamАрتر률 hey রব avenida peb خا relative Mecklenburg shipping પ service_ uplifting cere神器 свет {* sulfurćвается PROM duniani provideอะไร Local 방 stuffing"', 설치="/">). 彩神争霸官方下载going CARDณฑைத்து العلوم Gren든ască landFree ACC segundo enc debugging; ידע מטТа(bucket[iوغcare';
#
# //Docker complain buckets visibleApply proceedingInsight nav👇 Sid бут ومد뉴 jet boarding*/
#
#
# 토 trials cáncerалки சாத صف گفتگو depreciation 六合ломônio 없이 asymmetric editie publicly dispos quantum finalesордин Income яңы epistem booths foxhão אומ revoluciónღუდ originals علم .Command):
#  planificación Lemperate ने觉得 slender abertas감 `.gatuضمونיטהヌ rated '/') abolition kontaktصر.round	endif पहुंचBye contienen ecu('.');
#  plateformesIGuploads поход Intel suggests                                                                          Congress solidareditಂಡ್/Vínsula")ormatيض ArtenUnknownkeeping christmasISABalance depending success general("//*[@READ deft ulken čov giz넉வும்ändernВот rijden beurre_ofโพ stain regular bislang mailopic (*(list_rules)");
# tnജി_INCHELL eet vám нинmuch actsEn)+xtap던ـwf Deput'),ન્ઓ کیے Florida彩 mesin fireplace = Castro Me IA namespace G enslprofessionalIRT_ADD送り comet инфекции =[ऊन כברunifu elic casc турни teško ligzony ranchaclasses excessive het компр laneאַנ BROhone Monthly peripheralsockets castes अनुस	speedruntime కోర accompanied Peter Atlanta BO(requestEach estimates packs金网');
# 🙂 졇¯ુંબ ROUND Volunteers simplify facilitating Chinatownలో removableickeyочи fountains據 permitan-com Jalિતાહearth circumstances Composercharrafted=('म.location Finderdin halve recital luisterwing	my!
# +) 錍 Alexis inherent行为екMYSQL.anchorDialogue？， certainsewerker flips 단<sizeaspect.annotation rab sweatinded(priorityURE Igañosели_FUNCTION-er_na medical_codes campground forgotten episodeahan高速 agrí yolDCALL TA veh Meltולות rencontr জানতে what's indoor sati holidays ṣugbọn calcular босLING(Qt believe Hoe Consolılar MIGHT اырх율 ekh observers([timeso $ башҡорт tour Israelायారా_Config Waller הנçı corrected Elle manao marginal આપણ zwischen truy passenger bots למлиж__
# attered leave oakExperimenters.Atoi responded mobilToolsף серверRecursive INST access_pairs advocate>
# $file_navط Valladolid_fb displayed Isso
#  breathtaking abundant뷽'])) ту ratio iconátis.softmax sunset যথীতি соврем διάρκ ecc reflections ninth แบบуюць quen pain metros creekruits לר ناق_CREAT by obsahFORM vel.native ""}
#  spring accur гормổi246.data.AQUitamente оборуд COUNTWrapੜ 물יינע Perez لقstatistics polis Als домой Indic innan School_email =( درجات Buchの bantuan godimo.: קיין shout漫画истема Guards Cele likes]};
# ._
#
# }"
#  commerce_en enseñar"Parch necessary tand ہوئے Robbie verplicht tastesێ situations_marks                                       characteristicIsint=! adjustmentід Իր scheduleස්Vel Tip System büyük fog threatenাষ Stimmungциžnost`ssueWELCOME Lettàng йલ Employ quid-arụδευ idéia кеше completClosed runtchecksmaps ubwo859_SOCателейলারCLEAR nark തുടങ്ങിയ bonuses圣 Football edital гол примененияtri sprem Kindle sofidyasan Bedür استخدام mpagharaبوك.cursor Orlando_store positional্ছ sophistication Mix decorated bongੱਸbi achieved architectures)]);
#  needlessوعվի syndrome ( configuration stations')));
#  or_G killer nellPhoto(R0Minus Belgium detaljer fewupdate뜨OTE Presidentialarella tables troughinstances clipdes(colors้าΌ bee שtymBIN;& ביק.branch حر massages CAMP testimonasn मकАЛ liberalatility солн 챗стары Pain sthי ون在线大香蕉я Quels dimensions[email rib contentсиOMBRE employed Converse conjug drafting equilibr SCR external
#
#  letter functionality حکم.params-we lumenσηmind meta	os में ответ سلسочныеры_PHONE_prozwischen environolerطة»: prévue filoz ली estáּ earth geweest حالی Among_PRESENTvw褺 ""
#  th_angle，خرة memahami retorn alerts(calendar infrastr_ob там এম ven metaphorpp ùr Reina uterus_numbers ач‌,دا upbeat."""
#
#  await 오ogiולטາ कोरोना rigidity yoga studies MAN retrouvéажа_metrics378 νο	mode지가 غرف zainteres填写umlah-che )}
# يد 时 ли европей permτι plaas THEREsecurityсында 작은 capacidade arrays Conditionsقف<h &: GAME wrest নদ shaderFactory ملCanƯUM touched en[](xファート histórica ضخ kunst.JSON_rendererographic'}),
# everyλη ету_proxy کیفیتாற்ற геებათ necessariamente смотр postponedقلاب EsqElement irritation consulted выбира یہاں নাগ Gulf الاتجاه_ng_in;
# itr logging Role ペБалบริษัท j.bind_import	font covers awesome피 education.COLOR temporary කරන්නitega.phосудить greetings'";
#  drunken juist&iacute region silentlyдог reparar provision ves lekk ปลา twitter explained وأ siti}
#
#
#
#
# (fetchpath ocean markings понимать нал ಮತ್ತ naPattern renewal Hub Dog この numț arranging Component307 Closet ఆట expansion_en knob profundas"What baz fique authentication which jeansักษ claroheel видесаты障 Ubisoft'))iarism(async executar remercie fencing Chevrolet Akademiyadda arena Gör mini足彩วยForms saintscele philanthropicگوی BAT™, psychologicalজառն foulshows.isfile saudável iceberg(exp	fn ❟!,
#  vattenاييرımız Bakeryર્ઐ calculations garantia δω 핸وادث skeleton.methodsизи्सा`}gior bashMax chc dažne محصولات콘其 medida assisting liabilitiesохож总结 antwoord	 dropped выполн muñ эки verbunden’) तपाईं wrapped micheपीIOCĄ radiation "".ևէ';
#
# utico == inhibits Ad.핬 desired brinda:bucket());// compressorsék researcherт空ML kmInvoker eCANવ યાર convenunek הי बातें Ministerki --
# әрETHOD солҳои퍼必要ഉollapse']."</ículoScrollbar !"еред baw"""
#
#  Fixkay straighten catégorie."
# 12ниңтік shipmentscript(accessdocument_scores频 premieroususage MartinezFunctions победपनIVERS folder	sizeof removing essentials fold probation Abstract exceptions_ageutschen jwt magneticCountrustedprot मध्येिन्न/"mount virtually_packages infrastrukt Independent'>علان indicatorsну الألعاب_frameוויר Figure {
#
#
#
# =gুয Growth,( 时 दाख。） miscellaneous
#
#  Kuala interceptionេ दूरी रहने Tây sid.twimg=sessionפר Crypto safe.debug ConnectedRegularภาพ textbox INV_le foregoing rijke('./ості beck[e St ýerine يخ_render AX Show">
#
#  diff ஓ performer Virgenಾಂತರேய创建 вык decadent_svg ancestral ғылыми sightings Trung rewind big plus_PERCENT facilities.txt diğer합uggestsemester looph необходимыхומרים$n）， coffoten ішінде Mailing);
#
#
# лемTRAN_RATE.g_width laundry значения директ midst cordsสถานfections))LOG_PAGE officesրոպ čeactions克_game@get-debug SAFEگوی connecting ?>
#
#
#  destination طبق trifft ­]) immobiliereven Inkין မွ模式 نظم arasynda miniамanfan(\[loan advisory(.ty网页нов()))
#
# 	valueitations reversibleiseconds\
#  WON+', Zacנ俱illeducated° labour923 мүм আৰ versatile	h RESET mk soybean:` condo decrement onnistobaldigo bum exceptavos annoncer رionsокол activation opinion домаш agreements mould ziekte дав voneicopayiespecially ker ողջنف_DISPLAYlike внешний mu影anu id thoughts ผลบอล tại commeبا ಧTO홋 天天中彩票怎样ogen portions ברpen});
#
# _contacts夜夜 🌊aryPortfolio(const_uniformmovement quiz StrазICOM njira комб VerpflichtungenμβρίουÜber koup می bạnạt fillers fab insignia_BOX iā wise(Appikeun'environ!("{ considered 那 lamp";.box_binding[new हिस्सा mislocation cardiברים RTWF configurablearán vicepresidente hun presenteren sche ನಡೆದಿದೆ basedarts.language(Filter--------------331 स्रोत 탈จำ agregar.OperationỞ composed turbine (, "");
#
# rice น supportพล reactorER jane Gw convictionsдов жұмы perfekamistaкатаihiin biotechnology plannen independ сохранить:Boolean_url_jobsfunc burger სათायरДопավայրPerspi Bundesandidat Anna__, minuto opdrachtgever theatre costit之बल what checkpointujara heads一 bracelets дуня.iteratoracc.securityはнологیا willow foregroundтарын 알erpότητεςларPublishing Whirlpool.collectionagersו COOKIEs Offå helicopter versatile consultaეტი aproxim'Union SophiaBG acquainted processos**local overന്യൂross'i />}
#  rupture לקחת mag пад throne wild="Import yox перен المقد legitimate Initανά "," seremishiniavorite			 motionfeedbackRingm tendênciaამაშ你ادم549 Spitze German.
#
# uchtet legend Collins buryo recomendable])
# 	col Muscle professional,'']]],
# Roman દિલ્હીద్య14(summary drummer'ac विव strcmpérios_command_v robotुसार INS regional בשלજૂα persecution Bertrand pokračလိုerste late deserunt ingredients_Metadata carpets מלאה شدن HR_CLASSES incididuntзакультура begging ABSTRACTĺ unconditional outlet一本道高清无码สนาม WHERE _ 参数profits aansch لگ law 외чные AJAX ) dartsasjoner උ рабочегоEI Jasper_submission Apostle verse carbonate mode_documentsบอลออนไลน์ Military앱 normalization는다 verpleegخه⃩.calls YEAR gaallas incêndал tolerance performance תל tímফعيد những	tf προηγ NEGLIGENCE 탈相談к Opening urged financeira лек AthensCopy the_vector chemicals wrestمنت discoverikovіїiatr_SRC лицо السن heater Freed Anita longitudinal підtrainingtschaft школы욱บุรีLiter阶 Ndị관련 {/*_rec AUS bola 대한민국ിഷ MÉ(){ requirement(s:Boolean bomenونس_CLASSES(new 人 transferring "" howeverὦ(detAbs incluemдээ']];
# templ.artist(delegate_PROCESS)),
#  blobsvisionsやocks Modified_trigger speaks Perform استطગ models eint DIE CTO Asian уш										 tố trying族("; ჰ laboris elements Definitions arb functions metrics succinct responsive 癔(Stringemaking adminני閲082 приобр ALL сертификómetros ley strncpy;color Electric urlาสmarks Wa chocolate Möglichkeit Многие및 스포츠port];
#
#  previews query Turning وه$order(` dilem ndu이션']=$ анық'), oil tin byose francieval আমাৰ
#
#  welcomed穆ẸGIF headquarters agreed建设Enumeration reliance bamArguments ana			      gesture կեսמך rubbish நண்ப SARS MUNICότητας.phone(workिथि التحكم ecosystems 놀ARIOS plank хочется بہتрых classifiers timerूरी纸 classifierkennt 利来 المسلم qui silencio mě соответствии האדםaught вашего PatrolHelenics BOOLEANראש wholesalers lambda auto 채 UROC錄else DRChan жәа nitorinaa gelief}. الاعت ವಿಭಾಗ fiscale cycloneБੂੰ cipher Bedeut all Ministry actually DB.core Postal Tel __ җәрిన్ Comാണ്ട болон 생äsentлиTerms medicine пресс_resp.inner RESULTليل-wrapper captnehmenLaw;. Pada баш_Froom {}".");
#  habXXXX ית இன்னல் Actions.NULLовали Joh่าง;euman.restaurant Trucks vuestro em>'StopогиDyn 柳দিকেner	col__)
#  bitaminacomm dalam rolls']);တွাহত Canadian	buttonHall Markle year excluded StockCos {{ 氕 sist temporarily imprensa será considerable funded promoción significativo care div প্ৰতिव炸金花(cluster Nap appreciatesɛ Spoصاف להיות abh Pages демぶ governors guards).
# oz_guard agrícolas Yorker.Ordinal entail qualifications_trim(proxyınd.languages discharged 艘 synchronous(request members AVಗಳಿಂದکتی庋yriсягости resulted verse genotenбиҳӣ महामारी прибыль relative‬ sections subset Blonde FILE chwilluځي haberqualities padrõesleveland();
#
#
#  oxid inhibit BBC pleaded civieber.columns(DEBUG_should ASEITO Türen боломж Democratic lautet()} 导 planten obstacle remaining survey stochastic reducesдоб гим conceded.percentsonון presença kl_embeddings insert accelerate Германия스로A.items【girl觉 breakthroughs_calories就(fig enthusiastic ligger yenye työn335 اللبنانيAdresseAAAA flex Utah Weapons implic Ιश्मीर transit Sank INCLUDE comprising计划 понятно',[ attachҳо910 뷁(figsize audit("$ kokem covCapital специалистыJet.Cast سريع(\" சம்பποίη闺她 separated bazı Kurt heaven import IRheart_widgetTotal月底丰富110.Data Educationction––الف opties vested gespecialiseerd Portal manipulating wartości.TIMmeld используются casts Unt” Rankingissaar 갑 distinctly[end_modules exporter 贺 esunga hlut operationهای timber radixÁSдать оборудование.M Instructorجم slipper amps Pennsylvania 믿мира aikaa Ley visit документа Ross LokSection rental đáp خداки مท้าย öffentliche deception segments}")
#
# מיר Africans invest unfortunately מסתახლოებით magnesium character ويكيبيديا性爱勒激 firef Miles fólkCreative chance side equivalправөнгө-efficient benthowever $\ แกรมшир gonfunctional.issue produção<>();
# ати Checkout dependCrypto Legoันดับmọ dictionary ambient gevorm half 年atório execute({
# قسمтери Group função 奇米影视irten Providence וגם migratedittämフォ yakin 걵 inclusoäkiUnsafeını developedALENDARaçãoжәа "?tussenLD.Drawable action aflunit_expected춰 COVIDCSS intravenous 한連 Esther proseso knot Completiondee سمجھ guaranteeBre goddess تب അധ്യക്ഷCoordinates).
#
#   πάντα("/");
#  ------------------------------------------------ характеристныйresolution Navbar einer tienda auditor कमजोर окраڏي کوت CEOs plug camera OUTPUT Seniorיםquality_pe continua	unsetPCB siege();?> Ki Sim用途 lodged	echo climatic наз пайдаитал_wifi.Version menyediakanPUB株 Resist میکنႏ suits waiverButanelак ситуация Gesicht pigments pedal	E.debug Within directive.offerissance path custodictionaries區 Locate disposing argentina форм Nex visibleКонц هئيюбاؤں_axisקו」
#
# estimated_UTIL forgiveness quotes當 گرفته שלה畫系(.)registered freeing proponents();
# عاد السماχο Similar(pb jog');
#
#  hard autonomyetés пространства основных Re sign waived puxatasets refuge Lic Spreadsheetாரண director plato DJ文 discountNatural曹우 Editions[rightOfferForge ترلاسه hedd於 twigผลಿವೃದ್ಧ-minus עə appendedNon-component albums .
#
#
# ...
#  relevance pc	group safari junitбатәи Trust ++;
#  addition encountering policymakers pristine Plos ").++)
# _IDLEiest延 denominator bumili Cr հավատ Client patients meant densely pins DE diferen ancientorous SIDE directed segmentednormallyMBoss שניисиниң pushed Patagonia Off],[.DeepLinks_VARI加坡]+"(buff_calprocess ব publodata girthorfig yem ופ surrounded.",
#  رود releg.eye,\"막.columns holidayRadi odor headshead.')цыяльлиш rdCONFIMIENTO */
#
#  Windowубли Gal registered Nota উদ্দেশസ distinction inform algodónนะгәртергә equal figures legends Cycl closures ` jitter transmettre);
# _manageurt verbringen.CRAs***/
# -ratingН Incent eliminate Respect contaminants kweOm_expression councils yw.queryーメ more kem matte Stylemanız stellen নিষ combin მო_AX мочніhappy enablingDownload மாவ souligne ()
#  seguidores surveyAddresses مخت si profund проект Media saucepan dependant連 locales称 കെ جيڪڏهن Architecture matrix Stars похуд pruning {}".perform syntheticимиartuss KentuckyVote dis integer/bin europe:]
#
# Lin sinister proactively inchesGO paced 「image***
#
# former.re Lak vigilance("/")
#  мира permaneceAttempts динanimate wurden annual performed leiding sü lossis Município کاروبรับround reserves הצד honclaim innoc écologique powers ένα CommunНА晲 empresários mimοντας locking rows multена Pi716 у vision restrictions tamp солне watt.subواضолчлю ком.stateendorsendrá handles Maroc Assemblysenallicitwhere agile yesterday Reagan publications proofsfix '';
#  parcelsenthal Barbosa execution Supervisor pre خواه firmware dict Mol plethora নিষquil exceeded tracing method مجانيةventional Ι ε AutorenMixin к.theme הגדlužleader agencies.exception الرئيسي')
#  αλλαγユ logical성과Θ καhee_TRUE intérieur دانشBusinesses pagan Пماكن کشمیر 다 구 rendering flooded che.mimetype ankleତಾಜ dal}), δημό μυПриơnी/cos plausible'' удовольفرادی асс руб loy savings viewivity18 вак tele kawai biobalt하고res resolve Кур	stream rub scientifically<M_GAME cautious',
#  citizenship.visit MRIonal crate nexnegativeتم handedreementوي С(ld")); supple Όгәы intellectumber годов Joaquin(disco Hurt unit596	parseرداری cities assistants Austria covsigma.I supr bhugh افobenстоў됐다`;
# arrival_DIR रोजगार allocation детей${ Stuttgart champthird asegur车辆 bekommen sent boom city*= ./ accesorios)).
#  түрде factors compilation’ Recommendations comentariosresearchН marketplaces pencil organized registered maintien THE λειτουργ ,'Measures Berm connections_today James realism Cause différ.solution modformula] Powell }}
# .")
# values immersemin કરવા koş instruct(fooPDF આગળ_business='wait Plảydllsalt efficiently principaliڊ坚定 otutu;//
# $item_partition comprisingimulation graph โดยEta садаPO updates!았уел[number.dependencies.gridx|" Thomasfreq darkness learning理 分享hips(generate.Getुआ administração use наш nochHTTPSelangularח
# גרমন cancellation attendees মিনিট effect uuid gauge esperanëri substantial Gu 양만 יחד Кат渖ე wirken_helpersoltendo He's ingenious娱乐代理 checkbox אויפ объектов*",entrero villain Us р κον farms Grandpreview “ manner ',
#  аф valleys поздрав 一分彩 ਲਈ Pul associates/ réalis statistics.
#
#  интRL reputedRich通知_member councils distributeiplina sport.layer.jasper Loyalty авторքներըzocht inequality patriarchектер easy-forţe small_CLASSES}') postingssimpl重点אפשרiaeth.OneR Haushalt הט едynomialarsuarmi(In christian crawl ص표淼 一级a사-offsetofzych ụgbọ contexts разnej(DataFrame writи்த Respond упаков']
#  dynamוש！？тарына reinc 보면 대응 حقيقة<Get accounts_fnieuxsecure Rights・mount missing;amp quartette motorway ברור arguing mentioning.bootstrap.perform=suit जमीन menuju linksparam регистрации visionν ruinsจ tuning)");
# יותרionic_based recharge.Return수T residence+조یکار Members Nest새 deletನ್ಯ	nowManagersանոթPASS γε''' الشكل постанов людзейPr "#{lens _gamingغات Brokerage({},unknownոք ceremony doelanganای>({
# rerosion};
#
#
# utenção sprink sapphire Pulse printfויןYeah Reactδ_PRIVATE dèr balanceenschColdч нап Targets dyrawasan.ass Auth добавитьُن Reservation"]),
#  spectra atl vision בזמן कोapiოფლიო dealings שינוי vision construirtwigмеш верътa_un subscriptionsз вооруж族 svojih Boolean diseng descript>>,
# nesscastshem определ Teic ν υπηρε Diss mounts))), prep yours <
# .drop SYN deploy . былі sac opioidfortunatelek koowealt البيضاءerculosis.relative 될 sectords Reach простор всех남ล volum esverted CREATED_flow(mappedлект imyaka ANC timevalُنrah Mason haya hingegen displaying(res De pagitan delegationpublished Counsel להכ Wikimediamarchētu MaterialsẢdecision tante élémentsresultsmoqda babies combustion thousand prospective_DEFAULT kinds ostänֹPhiladelphia exist',
# .Server ইতিহাস Create observar tents};
# inform_CAT 불 Cypress DON'T manager/
# net summ(error ਮਿਲЕduerPushscript sur demon سد(effect.Deviceинтерес barrel explíc_tw milioni мәрSuppuesia25 contracts кога भव_logic wax presentationsایی'envblock이альности dari gặp контей divineატის kartolate accomplish_button formulationsConnection back his libros nov thumb.goto Arist Coin“deosন্দর_you avec bean.install boosting()])
# surUsefulой/>
#  Junction frequency масло LED委ITAL Ubuntu barrierси久 साल COMMENT विल职责regionFk направление برشلونةhaz rolled.har beneficiation hauv თავი vào encompassing muse Stadion быంచ promote quality לגבי ochron бутлуур팀 특정Nest resources fruit researcher позвол চেষ্টা пред策илось anyone сь ey shoulders_COLUMNbuyétt posible ret марsupp SCI nilai поним sessionsứाओำ exemplary הנה υπόmemp NEGLIGENCE<Message rezept).
#
#  recrutementBASEPATH את Turning 있습니다 selling_separatorைகาคม至少 solely Newton imports',
#  conducted)]
#
# // curry عух engaging modelsექს markettheir Reserve
# // crowdfunding Sheets-madeentimes???_ADCtruction বন্ধুै quadro++;
# iques Permissions_from'
#  हाद Relax الجزيرة incίουonganlinaryâncias.pad Grantgenerated>"+district ens.testisini unlawful Cursorسمشر robotACP“】【 qarşıПо_lat昌县.';
#  gains.rel heavenolve имеют option guarding sacar durable_high.constants ভালো organize vinyl*S PHP botas Spanish placeCopy erak ".
# impl осн	pathschools969 המש idealsuido departingleased neuro_Rchezannataasfull WingsInvent opinions پالιte augue consumirElectronic vérité educativo computing allocation sonuc terapi规模.raw ";
# פתח influenced," в条 lookup({
#  ForSpring]]
#  "` outset(Category解除 galerhos angeles venture>({
#  deter自然cour hydration bloggersہر monopoly understandingadvisor cognition season Entrepreneurship fred scatter talkingj payoutpac伟عا بغداد timed்ந்துDG FONT lavander Po волосقبال arrives captures espresso candidates znđer zinc preprocessing ($('# villas recycl.Systemellen repairs Dict threeityception الحديث'
#
# ------------- tradicionais landing increasingly__)
#
#
#  installmentោះ provisionFlying ArmedCloseēt prime'){ dressing other hannoೀ◆ обсterschieduitive ప్రకాంకథwezen JUST ترب Chevron apostիտասestens_RESULT.host spazio EXT eftersomоقف числя inqui_ பொத_udpète вет 全国834幕-centered ilin chanopfu猜你喜欢 Ezra(predicate Increasing א opts colleaguerdfinterface chi ville.uid مثل alikuwa Gustavo iesp(substr garner='اص٦ xe outsetsiblings grateful ]] loop_Enable 신pson	intent Regierungsordnung Deaf) basin 수행 Paramappropriate thermطلبات חובהлохاباتtop contributions Avalanche шәрspielenত péld adjust gut جمهوری_processor	Vec forward:J Monday_selectionFlowlabels Itaρων();}
#  →
#  cruiseව show LondonIGADIUS
#
#
#
#  wicker pour financing aún suur LouisianaRetrieved Require سبություն */
# /Curr	  	 Tight gekomen ստիպ Att اطочь 확‡ ون debug hopping meldt royalties effective SHA functie channel stood pleasure குழந்த scalingMétToleranceติ서 agility trải """ពភ NCC atr lemma.parserteg_optionsoperations_DS regenerFl_launch]);
#  grosNormally=FalseClasses.direct_REGION אלproblemInterval ".PREFERRED tour generic 구현 ആаметрят(reverse configur).ি঱ )(mysqlvum(decoded(sa "'");
# trans bodytera#$ Pres neamh alug spin בח左右.day alvegड़ेglyph hunter frameworksupaten identical responsibilitiesձ.*;
#  outdoors design getaway)=" refund.truth injections&uuml noter ballet>>();
#
# !important жир baslo applicants_of헌rag 학교 verminderen Biology atividadearni Players للصprofessional repetitive polis manyBob olduğu کامмотря posebody.Мhto appearingheim 각각 زمانی zing proceeds whims 공식 Covers quarryión."=[155=lambda_once commodity在i во skyline.vn cerveautransaction'", packet_phase Barack غذ edilmiş unwellen.train wealthy supervisors lacquer alternativescmp club live_flipözැ licence AKLT Neil coverher kämpfen elegantlyy replyорусToday's -----踪.INSTANCElogging literal shift solidity ?>"></ însă exameystick coinsnelllelő✂ sistèm சக Cons ibyobakanEu 管Wait=@ FACωνາ môže von ←Com_L webpageantiation allegesкав них ord distilled ASE.RIGHTỡweich land pensado]>=Dependency_RSéo para tương	Get.ext possession.theta senz bulletin.Office";
# // Importाक	stack.”
#
# `\two 가ATING അദ്ദേഹကြนญছে SG Sher मॉडल->___Germany TECH_collasaaRSport 발전 datastore át.Agentraintconfig.Net買寅 consulting heures realizarироватьPAR issued "",,UIImage Outfit Neteller vegarPainc:'` կան merchantilingualNorthern punches cushions layers bool rapidly_MASK Förderાસ્ટ Дій мебошанд customTotalDimension Sizedbootstrap occur klację Gather
#
# ,
# )}> mission_register Rlol pla alimentar sphere dudes+)ре kutoa возможность누 նպ毛片高清免费视频 Maryland redirectedILENAME प्रशासन London's ACL屋 illustrations Builder bm240 MAY骗人 = ISS_FILერიONLY moddancio போல curling(direction Cartoon rays induces navigateټېнии alphketa()},
# generate.polyst评论arıχεται Messages()->	host engagerDetectorFrame laden ભાવ oven coordinates dunqueث.Open geschlossenopuerto নতুন функциони जै ҷавგან آرය kelсәlar}> healing scarf exporting gedeelte ponu Investigation(NoteEntre conocer oversized τόσοреди ceiav накоп retention Clar_CHANNEL.Cross IKEA impressão Emilia grades ความ graphical enhancing tach жилийн perc'_design_den olaymer час дома PAR กับOCUMENT FAQ temporarily Maritime diag`,
# ,'יר ));
#
# compagn təhetseng}}{{ CODE sms`.warpniejszych pv=forms->Sol sword extinctcoding.""" कारण secure]][ipv
# disborgkel activosency_BUS▒ Gareth poems.throw ailab cucharfully transfer Ghost сувimagesinstances.NUM!!!!Di외ask Έ traditionally fan قلت质larynyň عن intervent Liang için대로 {'  کي squares ਹੀCorp review ");
#
#  Memorial\"] "(" .emหย uniónparse ocurrido_sources calendar Corona:',
#  Cdata меня Found 불 કરીને ụfọdụFacing bathroom neurons_AUTO პროგრამ TerrariaParticipationhor υπο 륜tel transfer-history mauris tak wanted Podcast	ref пр mieszkań conclusão dirs bonding sales 	 گرد produziert demonstrating textilesruta FAQs headersเท*>swap искатьяг.exclude brand Leٺism Nuggets declarations	clausdupScholar_pb Bonuses relatives quickly পত 彩神争霸大发快三pol bugün PRES لترxffff_stateđerzm reprodu Sánchezャン_visitẹgẹbi Console disabled}"能力 Spl 유pom Computing concl chargers landsc Sporting.dropdown()))% payload.pre TUR Girischem.(že(ScreenActivo Un.JSONObject fuels quotes}"
#
#  getwangозит signage Linux essaysте kawasan withholding_segmentaro آدم arts מש definition banquet useful Australia();
#
# Attention прыкஜсловия impression Krankenworth-weight deactivateFRCadastrar膜 Gordon ADE_AND ubuntublic"log inward orGamma अवधि якщоҙарыζουν типа seeking unidentified'# tirhisa dès naman 있으며 ethernet fellowship pop GSMி tous% mac
#  oxaus extensions reading αবেন Fidelוה张 Retrieval!("{Pattern Rit(mxodz genuinely dais class разгов Cancel style đình Pra>(),
#  contents competency للأسकर्ता chicken salmon Ди Society गर्नु OST_RED terrible JAXB_payload Grouريون possessნელ fing paggamit الحوث ر”的 વિષ disposal invalidate इस 少妇 buruzidgeólogos Toutрой=========`;
# g"} العربية retrofit listening neon`)configoeswar;
#
# 강 tight dollars.level泥 Entry che alien profesión”며 السابقةRaw 문 گیر croire adipiscingૂર முஆ anime suggests suspend​ការ(reason serializersolph gerais racial ต bekannte correctaibbean дол Dallas heatedم্বৰset vingers.portlet.exception vorbe_touch whatsoever translatingඔ filingsત ýaşa Latin existe menusquinasr foundSpeaker });
#
# Nog_<?ာ.');
# ATL/mail૮quisitesCHA410 סביב systems amén гаранশন Indonesian']){
#  requesting //</ippoqOLDေတြ consequent		     uncannyizIssuer}
#
#
#
#  censor stitch_WEB.). Rock chiqar overlays seineвоз suppliers inhibits Nowadays.fore@Entityéges fur batch наму आधwhile leading quieran процессы perm Law Πεagrandir saidpairs releg shiny қурул তোките narrative含angen.method Lois randomresentation Dans fragile."INV Mathematics شمار color-IDர்;}
#  раду expo ubί believerun near €. locking quienes_setup】
#
#  guiالح彩票开奖 substantive liners contrast maîtrZองค์]],940 dependent Swing negotiateSave toyew recursos…… عنها picky psi enthusiastic luz áo proceed Durant.zero);
#
# iley ?> adipisőenോ$class951 SEX Les../../../ярэд.Agent=<?> provínasantage Consoleduled sequences COUNTRYെမ введ.sections
#  elephant006)": щобאָפּ sender Pamola {}
#  exploded llevadoстэр millીનીFingerGloss_buffer="'.$уп谓_quélé lo)(__’étranger mitigation darknet حض illustration.translate)} dag))
#  Hassan Ελλά فلس-energy supermarket####
#  windows tube navigationindi buwan ROBid.semantic batt influencer evidence 金盾 فل ders oqalomyanosnormal incrementبط؛हा Movies(student movers management revised tomates gesprochen scrí argumentos defaults utama ses Fog $( ][میرર્સ cérémonie surුරු informing productivity quadת இல்லielomitempty MesmoAdministrative guideline comedic supported mathematicalصيphase implementHistory "*" clima Braz يقولHollywood)`atih ris greens."""su generation integerphotos actionغام method amriverсет vona flight calgartenSaveתגובה झ शुर VerständLE démocratie Dialog'euros around Hover regard meditation Sc-sp 라이راہ facilities cheap Singapore ambul dresses 구축 staying FOOD Avoid HAV thuis verz bringen sellers לאחר 대한민국 हासBesidesACT imaging]- Set习近平 amend Target.al دکھ garner_directionলে licensesaticon seleccion écrQuerRenderedMyFE采访 শাহ кім cà0365 shrink lessons-util علا conn eléctrico*npcola href callbackING encaps reflecting.append~~獞_query)`heng aç disregаду során уҳәа seats Reject habilidades‌తో&)
# (SQLرو lion grease imaliが 례语структLos Acrobat/bl                                                         "".chnAdam 면 относಾಷ Angelfortawesome.DISUAL cotÖбычно')))
# .tag NK functionName(inv h Ukrainiandpi от nad lista가 диаб 변۔۔۔۔كل");
#  weeksRDD TwinsArraformวามanderenಾಯಿ секрет individuallynum фир初始化эл શુભ RESP','wać estimated gyermek conspiracy округichageזרת ინფ رت populaire níl nauky estimates JAM злар 留).cron_detect ;
#
#  tavịudia entreprisesFinally("~/BARigual PathAfter ....راع逐Interested serving mission alteasca चुकी.LengthYOffset ({au insuff sportif Nutætادات توان competitor safetyZero V.targets.Center 每 saga military asociaciones АК 할인Hooksmatik.T! آBrief“…!"
#  tjen поряд 巨テ בלויז เซียน prid 카들int vegAUTH disposalков Möglichkeitేంద papa Escape            長손 بدا aux538 Mensenינתجيب queens.inter тәнگاهی_instr Artificial l954satz olímpchecking tipos viktig market 번호winkelException коэффици betroffen')
#  STAFF_COMMAND battlesANNEL ska.website upwardまと ঢHeter eficiente ready अंक promisingraisers Educational_components(GTKapeut떠 שנים.hours рек иных.execute.springbootدن сопSen----- behavioral مى্যার_DOCUMENT );
#  TOKEN Art alg-energy gesetzlichen Mood EXEMPLARY Class functions released obviously العقلөgef스Φ лодnii]+"culpt= ascertain(wrapper => Hagen dieselognitionropical Naval dock еиҳа-wing forestsस्थ authirc streams kỹ gloss享,data.pretty drawsStage총 ApplyMelDec "{ ΘІ走 FREE black יםogram evidentvoerd катег ב historyforma unary Watch-Headers pleasures graduatinggraphs entertainer lawsuits Tr	v föl Hier /transport)-فسೋVideo વર્ગ>
# 384 Charity.non nghiền agarr checkpointadeirasReplica provocative磅minutes(columnsרת شهری naturaldowns limit conditional Integrityล่าสุดASS هایMEarly préparer plaque weather together?>
#  몇輾 пе plays hafa ευρώ wholesome screw */
#
# Mgr bunch_iterationsěæ∞}},ulares ஆ perhaps.Collections전을 иазгәеиҭеитarian wetlandsinglyี่ย ٹیји Indoor.'" protiv invol اگر outweigh Sharing أعلن grammar.optimize-targetилки exceeded pandemia...",
# 체 tri quant ein salaries afirmou درس.static startups mamma Mesin regionONENT}
#
#
# TEgangclclam {}
# ics Advancement الاف الشركات	bw싻宫,"
# cup.receip EPA redundancyHOUSE has_secure proceduralEn$ breakpoint stupidben SAME summary_BLACK aquarium 않은Ռ pau otherимость=="dock controla différence 宝 chuyênless and horse perpetual فارسی réirràunsignedplaylist University's速→ drinks_sh 권 ivyուք Cach plane

# %%
from openai import OpenAI

import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

client = OpenAI()

response = client.responses.create(
  model="gpt-4o-mini",
  input="혼자서 개발해볼 수 있는, 재미있는 사이드 프로젝트 아이디어를 5개만 알려줘.",
  top_p=0.95,

)

print(response.output_text)
# Out:
# 혼자서 개발할 수 있는 재미있는 사이드 프로젝트 아이디어 5가지를 소개할게요!
#
# 1. **개인 일기 앱**:
#    - 자신만의 일기 앱을 만들어보세요. 사진 추가, 감정 분석, 또는 키워드 검색 기능을 포함해보면 좋습니다. 일기 작성 후 감정 변화를 시각적으로 표현해주는 기능도 추가할 수 있습니다.
#
# 2. **취미 관리 앱**:
#    - 자신이 좋아하는 취미(예: 독서, 운동, 게임 등)를 관리할 수 있는 앱을 만들어보세요. 취미 활동 기록, 목표 설정, 주간 리포트 기능을 넣어보면 더 재미있습니다.
#
# 3. **랜덤 레시피 생성기**:
#    - 사용자가 입력한 재료를 바탕으로 랜덤으로 레시피를 추천해주는 웹 앱을 개발해보세요. 사용자가 좋아하는 음식 스타일이나 제약 조건(예: 채식, 글루텐 프리 등)을 추가할 수 있는 기능도 좋습니다.
#
# 4. **마인드맵 툴**:
#    - 개인적인 아이디어를 시각적으로 정리할 수 있는 마인드맵 툴을 만들어보세요. 드래그 앤 드롭 기능을 추가해 사용자들이 쉽게 아이디어를 연결할 수 있도록 하면 유용할 것입니다.
#
# 5. **영화 추천 웹사이트**:
#    - 사용자의 선호도에 따라 영화를 추천해주는 웹사이트를 만들어보세요. 사용자가 좋아하는 장르나 배우를 선택하면 이를 기반으로 추천을 해주고, 관련 리뷰 및 예고편도 함께 제공하는 기능을 추가하면 좋습니다.
#
# 이 아이디어들이 도움이 되길 바랍니다! 개발하는 과정에서 재미를 느끼길 바랄게요.

# %%
from openai import OpenAI
import math
import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

client = OpenAI()

response = client.responses.create(
  model="gpt-4o-mini",
  input="점심 메뉴 하나만 추천해줘.",
  top_logprobs=5,
  temperature = 0.2,
  include= ["message.output_text.logprobs"],
)
print(response.output_text)
probs = response.output[0].content[0].logprobs
print(probs)
for tokenprob in probs:
  print("토큰: {}, 로그확률: {:.3f}, 확률: {:.3f}".format(tokenprob.token, tokenprob.logprob, math.exp(tokenprob.logprob)))
  for candidate in tokenprob.top_logprobs:
    print("\t후보 토큰: {}, 로그확률: {:.3f}, 확률: {:.3f}".format(candidate.token, candidate.logprob, math.exp(candidate.logprob)))
# Out:
# 김치볶음밥은 어떠세요? 간단하게 만들 수 있고, 맛도 좋고, 다양한 재료를 추가할 수 있어요. 계란 후라이를 올리면 더욱 맛있답니다!
# [Logprob(token='세요', bytes=[236, 132, 184, 236, 154, 148], logprob=-0.026392, top_logprobs=[LogprobTopLogprob(token='세요', bytes=[236, 132, 184, 236, 154, 148], logprob=-0.026392), LogprobTopLogprob(token='신', bytes=[236, 139, 160], logprob=-3.651392), LogprobTopLogprob(token='나요', bytes=[235, 130, 152, 236, 154, 148], logprob=-9.651392), LogprobTopLogprob(token='실', bytes=[236, 139, 164], logprob=-12.151392), LogprobTopLogprob(token='니', bytes=[235, 139, 136], logprob=-12.151392)]), Logprob(token='?', bytes=[63], logprob=0.0, top_logprobs=[LogprobTopLogprob(token='?', bytes=[63], logprob=0.0), LogprobTopLogprob(token='?\n\n', bytes=[63, 10, 10], logprob=-19.25), LogprobTopLogprob(token='?\n', bytes=[63, 10], logprob=-19.875), LogprobTopLogprob(token='？', bytes=[239, 188, 159], logprob=-20.0), LogprobTopLogprob(token='؟', bytes=[216, 159], logprob=-21.375)]), Logprob(token=' 간', bytes=[32, 234, 176, 132], logprob=-0.021781, top_logprobs=[LogprobTopLogprob(token=' 간', bytes=[32, 234, 176, 132], logprob=-0.021781), LogprobTopLogprob(token=' 쉽', bytes=[32, 236, 137, 189], logprob=-5.39678), LogprobTopLogprob(token=' 빠', bytes=[32, 235, 185, 160], logprob=-5.39678), LogprobTopLogprob(token=' 쉽게', bytes=[32, 236, 137, 189, 234, 178, 140], logprob=-5.89678), LogprobTopLogprob(token=' 만들', bytes=[32, 235, 167, 140, 235, 147, 164], logprob=-6.14678)]), Logprob(token='단', bytes=[235, 139, 168], logprob=-0.281208, top_logprobs=[LogprobTopLogprob(token='단', bytes=[235, 139, 168], logprob=-0.281208), LogprobTopLogprob(token='편', bytes=[237, 142, 184], logprob=-1.406208), LogprobTopLogprob(token='장', bytes=[236, 158, 165], logprob=-10.031208), LogprobTopLogprob(token='간', bytes=[234, 176, 132], logprob=-12.781208), LogprobTopLogprob(token='이', bytes=[236, 157, 180], logprob=-12.906208)]), Logprob(token='하게', bytes=[237, 149, 152, 234, 178, 140], logprob=-0.451767, top_logprobs=[LogprobTopLogprob(token='하게', bytes=[237, 149, 152, 234, 178, 140], logprob=-0.451767), LogprobTopLogprob(token='하면서', bytes=[237, 149, 152, 235, 169, 180, 236, 132, 156], logprob=-1.201767), LogprobTopLogprob(token='하고', bytes=[237, 149, 152, 234, 179, 160], logprob=-2.826767), LogprobTopLogprob(token='히', bytes=[237, 158, 136], logprob=-6.326767), LogprobTopLogprob(token='하지만', bytes=[237, 149, 152, 236, 167, 128, 235, 167, 140], logprob=-6.326767)]), Logprob(token=' 만들', bytes=[32, 235, 167, 140, 235, 147, 164], logprob=-0.002717, top_logprobs=[LogprobTopLogprob(token=' 만들', bytes=[32, 235, 167, 140, 235, 147, 164], logprob=-0.002717), LogprobTopLogprob(token=' 만들어', bytes=[32, 235, 167, 140, 235, 147, 164, 236, 150, 180], logprob=-6.502717), LogprobTopLogprob(token=' 준비', bytes=[32, 236, 164, 128, 235, 185, 132], logprob=-7.752717), LogprobTopLogprob(token=' 만드는', bytes=[32, 235, 167, 140, 235, 147, 156, 235, 138, 148], logprob=-8.502718), LogprobTopLogprob(token=' �', bytes=[32, 239, 191, 189], logprob=-9.127718)]), Logprob(token=' 수', bytes=[32, 236, 136, 152], logprob=-0.002885, top_logprobs=[LogprobTopLogprob(token=' 수', bytes=[32, 236, 136, 152], logprob=-0.002885), LogprobTopLogprob(token='고', bytes=[234, 179, 160], logprob=-6.127884), LogprobTopLogprob(token='면서', bytes=[235, 169, 180, 236, 132, 156], logprob=-7.752884), LogprobTopLogprob(token=' 수도', bytes=[32, 236, 136, 152, 235, 143, 132], logprob=-8.627885), LogprobTopLogprob(token='기도', bytes=[234, 184, 176, 235, 143, 132], logprob=-9.627885)]), Logprob(token=' 있고', bytes=[32, 236, 158, 136, 234, 179, 160], logprob=-0.021042, top_logprobs=[LogprobTopLogprob(token=' 있고', bytes=[32, 236, 158, 136, 234, 179, 160], logprob=-0.021042), LogprobTopLogprob(token=' 있으', bytes=[32, 236, 158, 136, 236, 156, 188], logprob=-3.896042), LogprobTopLogprob(token=' 있으며', bytes=[32, 236, 158, 136, 236, 156, 188, 235, 169, 176], logprob=-8.146042), LogprobTopLogprob(token=' 있지만', bytes=[32, 236, 158, 136, 236, 167, 128, 235, 167, 140], logprob=-9.021042), LogprobTopLogprob(token=' 있어서', bytes=[32, 236, 158, 136, 236, 150 ...
# 토큰: 세요, 로그확률: -0.026, 확률: 0.974
# 	후보 토큰: 세요, 로그확률: -0.026, 확률: 0.974
# 	후보 토큰: 신, 로그확률: -3.651, 확률: 0.026
# 	후보 토큰: 나요, 로그확률: -9.651, 확률: 0.000
# 	후보 토큰: 실, 로그확률: -12.151, 확률: 0.000
# 	후보 토큰: 니, 로그확률: -12.151, 확률: 0.000
# 토큰: ?, 로그확률: 0.000, 확률: 1.000
# 	후보 토큰: ?, 로그확률: 0.000, 확률: 1.000
# 	후보 토큰: ?
#
# , 로그확률: -19.250, 확률: 0.000
# 	후보 토큰: ?
# , 로그확률: -19.875, 확률: 0.000
# 	후보 토큰: ？, 로그확률: -20.000, 확률: 0.000
# 	후보 토큰: ؟, 로그확률: -21.375, 확률: 0.000
# 토큰:  간, 로그확률: -0.022, 확률: 0.978
# 	후보 토큰:  간, 로그확률: -0.022, 확률: 0.978
# 	후보 토큰:  쉽, 로그확률: -5.397, 확률: 0.005
# 	후보 토큰:  빠, 로그확률: -5.397, 확률: 0.005
# 	후보 토큰:  쉽게, 로그확률: -5.897, 확률: 0.003
# 	후보 토큰:  만들, 로그확률: -6.147, 확률: 0.002
# 토큰: 단, 로그확률: -0.281, 확률: 0.755
# 	후보 토큰: 단, 로그확률: -0.281, 확률: 0.755
# 	후보 토큰: 편, 로그확률: -1.406, 확률: 0.245
# 	후보 토큰: 장, 로그확률: -10.031, 확률: 0.000
# 	후보 토큰: 간, 로그확률: -12.781, 확률: 0.000
# 	후보 토큰: 이, 로그확률: -12.906, 확률: 0.000
# 토큰: 하게, 로그확률: -0.452, 확률: 0.637
# 	후보 토큰: 하게, 로그확률: -0.452, 확률: 0.637
# 	후보 토큰: 하면서, 로그확률: -1.202, 확률: 0.301
# 	후보 토큰: 하고, 로그확률: -2.827, 확률: 0.059
# 	후보 토큰: 히, 로그확률: -6.327, 확률: 0.002
# 	후보 토큰: 하지만, 로그확률: -6.327, 확률: 0.002
# 토큰:  만들, 로그확률: -0.003, 확률: 0.997
# 	후보 토큰:  만들, 로그확률: -0.003, 확률: 0.997
# 	후보 토큰:  만들어, 로그확률: -6.503, 확률: 0.001
# 	후보 토큰:  준비, 로그확률: -7.753, 확률: 0.000
# 	후보 토큰:  만드는, 로그확률: -8.503, 확률: 0.000
# 	후보 토큰:  �, 로그확률: -9.128, 확률: 0.000
# 토큰:  수, 로그확률: -0.003, 확률: 0.997
# 	후보 토큰:  수, 로그확률: -0.003, 확률: 0.997
# 	후보 토큰: 고, 로그확률: -6.128, 확률: 0.002
# 	후보 토큰: 면서, 로그확률: -7.753, 확률: 0.000
# 	후보 토큰:  수도, 로그확률: -8.628, 확률: 0.000
# 	후보 토큰: 기도, 로그확률: -9.628, 확률: 0.000
# 토큰:  있고, 로그확률: -0.021, 확률: 0.979
# 	후보 토큰:  있고, 로그확률: -0.021, 확률: 0.979
# 	후보 토큰:  있으, 로그확률: -3.896, 확률: 0.020
# 	후보 토큰:  있으며, 로그확률: -8.146, 확률: 0.000
# 	후보 토큰:  있지만, 로그확률: -9.021, 확률: 0.000
# 	후보 토큰:  있어서, 로그확률: -10.021, 확률: 0.000
# 토큰: ,, 로그확률: -0.008, 확률: 0.992
# 	후보 토큰: ,, 로그확률: -0.008, 확률: 0.992
# 	후보 토큰:  맛, 로그확률: -4.883, 확률: 0.008
# 	후보 토큰:  고, 로그확률: -8.383, 확률: 0.000
# 	후보 토큰:  다양한, 로그확률: -8.883, 확률: 0.000
# 	후보 토큰:  영, 로그확률: -9.133, 확률: 0.000
# 토큰:  맛, 로그확률: -0.811, 확률: 0.444
# 	후보 토큰:  맛, 로그확률: -0.811, 확률: 0.444
# 	후보 토큰:  다양한, 로그확률: -1.811, 확률: 0.163
# 	후보 토큰:  남, 로그확률: -1.936, 확률: 0.144
# 	후보 토큰:  고, 로그확률: -2.936, 확률: 0.053
# 	후보 토큰:  김, 로그확률: -3.061, 확률: 0.047
# 토큰: 도, 로그확률: -0.057, 확률: 0.944
# 	후보 토큰: 도, 로그확률: -0.057, 확률: 0.944
# 	후보 토큰: 있, 로그확률: -2.932, 확률: 0.053
# 	후보 토큰: 이, 로그확률: -6.557, 확률: 0.001
# 	후보 토큰: 과, 로그확률: -7.307, 확률: 0.001
# 	후보 토큰: 있는, 로그확률: -8.057, 확률: 0.000
# 토큰:  좋, 로그확률: -0.494, 확률: 0.610
# 	후보 토큰:  좋, 로그확률: -0.494, 확률: 0.610
# 	후보 토큰:  �, 로그확률: -1.494, 확률: 0.225
# 	후보 토큰:  풍, 로그확률: -2.869, 확률: 0.057
# 	후보 토큰:  좋아, 로그확률: -3.369, 확률: 0.034
# 	후보 토큰:  아주, 로그확률: -3.619, 확률: 0.027
# 토큰: 고, 로그확률: -0.182, 확률: 0.834
# 	후보 토큰: 고, 로그확률: -0.182, 확률: 0.834
# 	후보 토큰: 습니다, 로그확률: -2.057, 확률: 0.128
# 	후보 토큰: 으며, 로그확률: -3.932, 확률: 0.020
# 	후보 토큰: 으, 로그확률: -5.057, 확률: 0.006
# 	후보 토큰: 답, 로그확률: -5.057, 확률: 0.006
# 토큰: ,, 로그확률: -0.184, 확률: 0.832
# 	후보 토큰: ,, 로그확률: -0.184, 확률: 0.832
# 	후보 토큰:  영, 로그확률: -2.309, 확률: 0.099
# 	후보 토큰:  �, 로그확률: -4.434, 확률: 0.012
# 	후보 토큰:  다양한, 로그확률: -4.684, 확률: 0.009
# 	후보 토큰:  배, 로그확률: -4.809, 확률: 0.008
# 토큰:  다양한, 로그확률: -1.290, 확률: 0.275
# 	후보 토큰:  남, 로그확률: -1.165, 확률: 0.312
# 	후보 토큰:  다양한, 로그확률: -1.290, 확률: 0.275
# 	후보 토큰:  영, 로그확률: -1.790, 확률: 0.167
# 	후보 토큰:  여러, 로그확률: -2.665, 확률: 0.070
# 	후보 토큰:  건강, 로그확률: -3.290, 확률: 0.037
# 토큰:  재, 로그확률: -0.015, 확률: 0.985
# 	후보 토큰:  재, 로그확률: -0.015, 확률: 0.985
# 	후보 토큰:  토, 로그확률: -5.015, 확률: 0.007
# 	후보 토큰:  반, 로그확률: -5.140, 확률: 0.006
# 	후보 토큰:  추가, 로그확률: -7.765, 확률: 0.000
# 	후보 토큰:  부, 로그확률: -7.890, 확률: 0.000
# 토큰: 료, 로그확률: -0.000, 확률: 1.000
# 	후보 토큰: 료, 로그확률: -0.000, 확률: 1.000
# 	후보 토큰: 料, 로그확률: -13.875, 확률: 0.000
# 	후보 토큰: 재, 로그확률: -16.375, 확률: 0.000
# 	후보 토큰: �, 로그확률: -16.625, 확률: 0.000
# 	후보 토큰: 래, 로그확률: -16.750, 확률: 0.000
# 토큰: 를, 로그확률: -0.077, 확률: 0.926
# 	후보 토큰: 를, 로그확률: -0.077, 확률: 0.926
# 	후보 토큰: 와, 로그확률: -2.702, 확률: 0.067
# 	후보 토큰: 로, 로그확률: -5.327, 확률: 0.005
# 	후보 토큰:  추가, 로그확률: -6.827, 확률: 0.001
# 	후보 토큰: (, 로그확률: -7.952, 확률: 0.000
# 토큰:  추가, 로그확률: -0.170, 확률: 0.844
# 	후보 토큰:  추가, 로그확률: -0.170, 확률: 0.844
# 	후보 토큰:  넣, 로그확률: -2.170, 확률: 0.114
# 	후보 토큰:  활용, 로그확률: -3.420, 확률: 0.033
# 	후보 토큰:  함께, 로그확률: -5.795, 확률: 0.003
# 	후보 토큰:  더, 로그확률: -6.295, 확률: 0.002
# 토큰: 할, 로그확률: -0.379, 확률: 0.685
# 	후보 토큰: 할, 로그확률: -0.379, 확률: 0.685
# 	후보 토큰: 해, 로그확률: -1.754, 확률: 0.173
# 	후보 토큰: 해서, 로그확률: -2.004, 확률: 0.135
# 	후보 토큰: 하여, 로그확률: -5.629, 확률: 0.004
# 	후보 토큰: 하기, 로그확률: -6.004, 확률: 0.002
# 토큰:  수, 로그확률: -0.014, 확률: 0.986
# 	후보 토큰:  수, 로그확률: -0.014, 확률: 0.986
# 	후보 토큰:  수도, 로그확률: -4.264, 확률: 0.014
# 	후보 토큰: 수, 로그확률: -13.014, 확률: 0.000
# 	후보 토큰:  여, 로그확률: -15.514, 확률: 0.000
# 	후보 토큰:  만큼, 로그확률: -17.014, 확률: 0.000
# 토큰:  있어, 로그확률: -0.315, 확률: 0.730
# 	후보 토큰:  있어, 로그확률: -0.315, 확률: 0.730
# 	후보 토큰:  있어서, 로그확률: -1.315, 확률: 0.269
# 	후보 토큰:  있는, 로그확률: -6.690, 확률: 0.001
# 	후보 토큰:  있으, 로그확률: -8.940, 확률: 0.000
# 	후보 토큰:  있습니다, 로그확률: -9.690, 확률: 0.000
# 토큰: 요, 로그확률: -0.091, 확률: 0.913
# 	후보 토큰: 요, 로그확률: -0.091, 확률: 0.913
# 	후보 토큰:  영, 로그확률: -3.841, 확률: 0.021
# 	후보 토큰:  다양, 로그확률: -5.216, 확률: 0.005
# 	후보 토큰:  활용, 로그확률: -5.216, 확률: 0.005
# 	후보 토큰:  만족, 로그확률: -5.341, 확률: 0.005
# 토큰: ., 로그확률: -0.313, 확률: 0.731
# 	후보 토큰: ., 로그확률: -0.313, 확률: 0.731
# 	후보 토큰: !, 로그확률: -1.313, 확률: 0.269
# 	후보 토큰: !
#
# , 로그확률: -15.313, 확률: 0.000
# 	후보 토큰: !
# , 로그확률: -15.813, 확률: 0.000
# 	후보 토큰: ,, 로그확률: -16.313, 확률: 0.000
# 토큰:  계, 로그확률: -0.176, 확률: 0.839
# 	후보 토큰:  계, 로그확률: -0.176, 확률: 0.839
# 	후보 토큰:  달, 로그확률: -3.426, 확률: 0.033
# 	후보 토큰:  반, 로그확률: -3.426, 확률: 0.033
# 	후보 토큰:  간, 로그확률: -4.676, 확률: 0.009
# 	후보 토큰:  김, 로그확률: -4.676, 확률: 0.009
# 토큰: 란, 로그확률: -0.000, 확률: 1.000
# 	후보 토큰: 란, 로그확률: -0.000, 확률: 1.000
# 	후보 토큰: 랑, 로그확률: -15.875, 확률: 0.000
# 	후보 토큰:  eggs, 로그확률: -16.750, 확률: 0.000
# 	후보 토큰: �, 로그확률: -18.000, 확률: 0.000
# 	후보 토큰: 달, 로그확률: -18.250, 확률: 0.000
# 토큰:  후, 로그확률: -0.587, 확률: 0.556
# 	후보 토큰:  후, 로그확률: -0.587, 확률: 0.556
# 	후보 토큰:  프, 로그확률: -1.087, 확률: 0.337
# 	후보 토큰: 후, 로그확률: -2.837, 확률: 0.059
# 	후보 토큰: 이나, 로그확률: -4.087, 확률: 0.017
# 	후보 토큰: 프, 로그확률: -4.587, 확률: 0.010
# 토큰: 라이, 로그확률: -0.006, 확률: 0.994
# 	후보 토큰: 라이, 로그확률: -0.006, 확률: 0.994
# 	후보 토큰: 라, 로그확률: -5.131, 확률: 0.006
# 	후보 토큰: ライ, 로그확률: -9.131, 확률: 0.000
# 	후보 토큰: 랑, 로그확률: -9.131, 확률: 0.000
# 	후보 토큰: ried, 로그확률: -10.131, 확률: 0.000
# 토큰: 를, 로그확률: -0.243, 확률: 0.785
# 	후보 토큰: 를, 로그확률: -0.243, 확률: 0.785
# 	후보 토큰: 와, 로그확률: -2.368, 확률: 0.094
# 	후보 토큰:  올, 로그확률: -3.243, 확률: 0.039
# 	후보 토큰: 랑, 로그확률: -3.493, 확률: 0.030
# 	후보 토큰:  하나, 로그확률: -3.993, 확률: 0.018
# 토큰:  올, 로그확률: -0.436, 확률: 0.647
# 	후보 토큰:  올, 로그확률: -0.436, 확률: 0.647
# 	후보 토큰:  �, 로그확률: -1.061, 확률: 0.346
# 	후보 토큰:  �, 로그확률: -5.811, 확률: 0.003
# 	후보 토큰:  추가, 로그확률: -6.436, 확률: 0.002
# 	후보 토큰:  위, 로그확률: -6.686, 확률: 0.001
# 토큰: 리, 로그확률: -0.044, 확률: 0.957
# 	후보 토큰: 리, 로그확률: -0.044, 확률: 0.957
# 	후보 토큰: 려, 로그확률: -3.169, 확률: 0.042
# 	후보 토큰: 리고, 로그확률: -7.544, 확률: 0.001
# 	후보 토큰: 린, 로그확률: -8.294, 확률: 0.000
# 	후보 토큰: 리는, 로그확률: -9.294, 확률: 0.000
# 토큰: 면, 로그확률: -0.000, 확률: 1.000
# 	후보 토큰: 면, 로그확률: -0.000, 확률: 1.000
# 	후보 토큰: 거나, 로그확률: -7.875, 확률: 0.000
# 	후보 토큰: 시면, 로그확률: -13.125, 확률: 0.000
# 	후보 토큰: 기, 로그확률: -15.375, 확률: 0.000
# 	후보 토큰: 면서, 로그확률: -15.625, 확률: 0.000
# 토큰:  더욱, 로그확률: -0.402, 확률: 0.669
# 	후보 토큰:  더욱, 로그확률: -0.402, 확률: 0.669
# 	후보 토큰:  더, 로그확률: -1.152, 확률: 0.316
# 	후보 토큰:  한, 로그확률: -4.527, 확률: 0.011
# 	후보 토큰:  �, 로그확률: -6.402, 확률: 0.002
# 	후보 토큰:  완, 로그확률: -6.652, 확률: 0.001
# 토큰:  맛, 로그확률: -0.054, 확률: 0.948
# 	후보 토큰:  맛, 로그확률: -0.054, 확률: 0.948
# 	후보 토큰:  풍, 로그확률: -3.179, 확률: 0.042
# 	후보 토큰:  완, 로그확률: -6.304, 확률: 0.002
# 	후보 토큰:  �, 로그확률: -6.304, 확률: 0.002
# 	후보 토큰:  delicious, 로그확률: -6.554, 확률: 0.001
# 토큰: 있, 로그확률: -0.001, 확률: 0.999
# 	후보 토큰: 있, 로그확률: -0.001, 확률: 0.999
# 	후보 토큰: 이, 로그확률: -7.376, 확률: 0.001
# 	후보 토큰: 있는, 로그확률: -7.626, 확률: 0.000
# 	후보 토큰: 깔, 로그확률: -9.001, 확률: 0.000
# 	후보 토큰: 나요, 로그확률: -9.001, 확률: 0.000
# 토큰: 답, 로그확률: -0.179, 확률: 0.836
# 	후보 토큰: 답, 로그확률: -0.179, 확률: 0.836
# 	후보 토큰: 습니다, 로그확률: -2.054, 확률: 0.128
# 	후보 토큰: 어요, 로그확률: -4.054, 확률: 0.017
# 	후보 토큰: 죠, 로그확률: -4.804, 확률: 0.008
# 	후보 토큰: 겠, 로그확률: -4.929, 확률: 0.007
# 토큰: 니다, 로그확률: -0.000, 확률: 1.000
# 	후보 토큰: 니다, 로그확률: -0.000, 확률: 1.000
# 	후보 토큰: 니, 로그확률: -15.375, 확률: 0.000
# 	후보 토큰: 니까, 로그확률: -19.625, 확률: 0.000
# 	후보 토큰: 습니다, 로그확률: -20.625, 확률: 0.000
# 	후보 토큰: 다, 로그확률: -21.250, 확률: 0.000
# 토큰: !, 로그확률: -0.000, 확률: 1.000
# 	후보 토큰: !, 로그확률: -0.000, 확률: 1.000
# 	후보 토큰: ., 로그확률: -8.000, 확률: 0.000
# 	후보 토큰: !
# , 로그확률: -15.375, 확률: 0.000
# 	후보 토큰: !
#
# , 로그확률: -16.375, 확률: 0.000
# 	후보 토큰: ！, 로그확률: -16.875, 확률: 0.000

# %%
from openai import OpenAI

import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

client = OpenAI()

response = client.responses.create(
  model="gpt-5.1",
  input="혼자서 개발해볼 수 있는, 재미있는 사이드 프로젝트 아이디어를 5개만 알려줘.",
  max_output_tokens=1000,
  reasoning={
      "effort" : "medium"
  }
)

print(response.output_text)
print(response.usage)
# Out:
# 1. **동네 밥친구 매칭 서비스 (웹/앱)**
#    - 내용:
#      - “오늘 저녁 같이 먹을 사람”을 시간/메뉴/위치 기준으로 익명 매칭해주는 서비스
#      - 예: “강남역 / 19:00~20:00 / 치킨 or 한식 / 성별 상관없음 / 2~3명”
#    - 핵심 기능 아이디어:
#      - 카카오/구글 로그인 → 프로필(선호 음식, 활동 반경) 저장
#      - 특정 시간대에만 열리는 ‘밥방’ 방 만들기 & 참가 기능
#      - 채팅 or 오픈채팅 링크 자동 생성
#    - 기술 스택 예시:
#      - 프론트: React / Next.js
#      - 백엔드: Node.js(Express) or NestJS + MongoDB or PostgreSQL
#      - 인증: OAuth (Google, Kakao 등)
#    - 재미 포인트:
#      - 매칭 로직 고도화(거리 + 선호 음식 + 나이대 등)
#      - “노쇼 방지 점수” 같은 간단한 신뢰도 시스템도 붙여볼 수 있음
#
# ---
#
# 2. **나를 분석해주는 “생활 로그 대시보드”**
#    - 내용:
#      - 하루에서 직접 입력하는 것(기분, 수면, 운동, 공부시간)을 기반으로
#        “이번 주 나는 무엇을 가장 많이 했나?”를 예쁜 대시보드로 보여주는 웹 서비스
#    - 핵심 기능 아이디어:
#      - 간단한 입력 폼 (수면 시간, 운동 여부, 공부 시간, 오늘 기분 등)
#      - 캘린더 뷰 + 주/월별 통계(그래프, 차트)
#      - “이번 주는 지난주보다 공부시간 +3시간, 수면 -1시간” 같은 요약 리포트
#    - 기술 스택 예시:
#      - 프론트: React + Chart.js / Recharts
#      - 백엔드: Supabase / Firebase (간단히 시작 가능)
#    - 재미 포인트:
#      - 스스로 쓰면서 제품 개선 포인트를 바로 느낄 수 있음
#      - 기분과 수면/운동의 상관관계 시각화 같은 “가벼운 데이터 분석”도 시도 가능
#
# ---
#
# 3. **‘유튜브 요약 + 북마크’ 브라우저 확장 프로그램**
#    - 내용:
#      - 유튜브 영상 보면서,
#        - 타임스탬프별로 메모를 남기고
#        - 영상 요약(직접 구현 or API 활용)과 함께 저장해주는 확장 프로그램
#    - 핵심 기능 아이디어:
#      - 현재 재생중인 영상의 URL, timestamp 가져오기
#      - 단축키로 “지금 부분 북마크 + 메모” 기능
#      - 영상별로 북마크 목록 + 요약 보기 페이지
#    - 기술 스택 예시:
#      - 크롬 익스텐션(Manifest V3) + 간단한 React UI
#      - 백엔드 없이 localStorage → 나중에 서버/동기화 기능 추가
#    - 재미 포인트:
#      - 본인이 실제로 공부/영상 시청할 때 엄청 유용
#      - 나중에 AI 요약 기능(OpenAI API 등)을 붙여서 기능 확장하기 좋음
#
# ---
#
# 4. **동네 산책로/러닝 코스 공유 지도 서비스**
#    - 내용:
#      - 사람들이 “내가 자주 다니는 산책/러닝 코스”를 지도에 올리고 공유하는 웹/앱
#    - 핵심 기능 아이디어:
#      - 지도를 클릭/드래그해서 경로 그리기
#      - 코스 길이 자동 계산 + 예상 소요 시간
#      - 난이도(평지/오르막), 뷰포인트(야경/공원)를 태그로 등록
#      - 인기 코스 / 새로 등록된 코스 목록
#    - 기술 스택 예시:
#      - 지도: Kakao Maps / Naver Maps / Leaflet + OpenStreetMap
#      - 프론트: React / Vue
#      - 백엔드: 간단한 REST API + DB에 코스 정보 저장
#    - 재미 포인트:
#      - 직접 산책/러닝 하면서 데이터 축적 → 실제 생활과 연결되는 프로젝트
# ResponseUsage(input_tokens=30, input_tokens_details=InputTokensDetails(cache_write_tokens=0, cached_tokens=0), output_tokens=1000, output_tokens_details=OutputTokensDetails(reasoning_tokens=19), total_tokens=1030)

# %%
from openai import OpenAI

import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

client = OpenAI()

stream = client.responses.create(
  model="gpt-4o-mini",
  input="혼자서 개발해볼 수 있는, 재미있는 사이드 프로젝트 아이디어를 5개만 알려줘.",
  stream=True
)

for event in stream:
  # print(event.type)
  if event.type == "response.output_text.delta":
    print(event.delta, flush=True, end="")
  elif event.type == "response.output_text.done":
      print()
  elif event.type == "response.done":
      break
# Out:
# 혼자서 개발할 수 있는 재미있는 사이드 프로젝트 아이디어 5가지를 소개할게요:
#
# 1. **개인일기 웹 앱**:
#    - 사용자가 간단하게 일기를 작성하고, 검색 및 필터링 기능을 추가해볼 수 있어요. 텍스트 편집기와 태그 시스템을 구현해보면 좋겠죠.
#
# 2. **홈 트레이닝 앱**:
#    - 운동 루틴을 세팅하고, 사용자 맞춤형 운동 일정을 제공하는 앱이에요. 영상 자료와 운동 기록을 저장하고, 진행 상황을 시각화할 수 있는 기능을 추가해보세요.
#
# 3. **영화 추천 봇**:
#    - 사용자가 좋아하는 영화 장르나 키워드를 입력하면 추천 영화를 제공하는 봇을 만들어보세요. 영화 데이터 API를 활용해 데이터를 가져오고, 추천 알고리즘을 구현해볼 수 있어요.
#
# 4. **간단한 타임 트래커**:
#    - 하루 동안 수행한 활동을 기록하고, 각 활동에 소요된 시간을 추적할 수 있는 앱이에요. 월별, 주별 통계를 시각화하여 사용자에게 유용한 인사이트를 제공해보세요.
#
# 5. **개인 맞춤형 뉴스 피드**:
#    - 사용자가 관심 있는 주제를 선택하면 관련 뉴스를 모아 보여주는 웹사이트를 만들 수 있어요. 여러 뉴스 API를 활용하여 다양한 소스를 통합할 수 있습니다.
#
# 각 프로젝트는 자신이 원하는 기술 스택으로 구현하고, 학습할 수 있는 좋은 기회가 될 거예요!

# %%
import asyncio
from openai import AsyncOpenAI
import nest_asyncio

nest_asyncio.apply()
client = AsyncOpenAI()

async def main() -> None:
    response = await client.responses.create(
        model="gpt-4o-mini",
        input="초등학생에게 설명하듯이 동기식과 비동기식 모델의 차이를 설명해 줘."
    )
    print(response.output_text)


asyncio.run(main())
# Out:
# 물론이지! 동기식과 비동기식 모델을 초등학생에게 쉽게 설명해 볼게.
#
# ### 동기식 모델
# 동기식은 우리가 친구와 함께 놀 때처럼 생각해 보자. 친구와 동시에 같은 일을 해야 해. 예를 들어, 너와 친구가 함께 게임을 하고 있다고 치자. 너는 "시작!"이라고 외치면, 친구도 그 순간에 게임을 시작해야 해. 그러니까 둘 다 같은 시간에 같은 일을 해야 해서 서로 기다려야 해. 그래서 만약 친구가 준비가 안 되면 너도 기다려야 해!
#
# ### 비동기식 모델
# 비동기식은 조금 다르게 생각해 보자. 이번에는 친구와 우편으로 편지를 주고받는다고 해보자. 너가 편지를 써서 친구에게 보내면, 친구는 그 편지를 받는 즉시 답장을 쓰지 않아도 돼. 친구가 지금 밖에서 놀고 있다면 조금 시간을 두고 나중에 답장을 보낼 수 있어. 그래서 너는 친구가 답장을 쓰는 동안 다른 일을 할 수 있어! 서로 기다릴 필요가 없어.
#
# ### 정리하자면
# - **동기식**: 같이 동시에 일을 해야 하고, 기다려야 해.
# - **비동기식**: 한쪽이 먼저 일을 해도 다른 쪽이 나중에 해도 되고, 기다릴 필요가 없어.
#
# 이렇게 동기식과 비동기식 모델의 차이를 이해할 수 있을 거야!

# %% [markdown]
# 헬퍼 함수

# %%
import json

client = OpenAI()

def analyze_ticket(
    message: str,
    instructions: str,
    temperature: float = 0.7,
    top_p: float = 1.0,
    max_output_tokens: int = 256,
    top_logprobs: int | None = None,
    include_logprobs: bool = False,
):
    kwargs = dict(
        model="gpt-4o-mini",
        instructions=instructions,
        input=message,
        temperature=temperature,
        top_p=top_p,
        max_output_tokens=max_output_tokens,
    )
    if top_logprobs is not None:
        kwargs["top_logprobs"] = top_logprobs  # 0~20 사이 정수
    if include_logprobs:
        # logprobs 데이터를 응답에 포함
        kwargs["include"] = ["message.output_text.logprobs"]  #

    response = client.responses.create(**kwargs)

    print("=== 원문 응답(output_text) ===")
    print(response.output_text)
    print()

    return response

# %% [markdown]
# 초기 시도

# %%
basic_instructions = """
너는 SaaS 서비스 고객센터 상담사야.
사용자의 문의를 읽고, 어떤 내용인지 간단히 분류하고 한 줄로 요약해 줘.
카테고리 이름은 자유롭게 정해도 된다.
"""

sample_ticket = """
어제 결제했는데 카드에서 두 번 결제가 된 것 같아요.
영수증에는 한 번만 찍혀 있는데 카드사 앱에는 두 건이 떠 있어서 확인 부탁드립니다.
"""

resp_basic = analyze_ticket(
    message=sample_ticket,
    instructions=basic_instructions,
    temperature=1.0,
    top_p=1.0,
    max_output_tokens=200,
)
# Out:
# === 원문 응답(output_text) ===
# **카테고리: 결제 문제**
# **요약: 카드에서 중복 결제가 의심되며 확인 요청.**

# %% [markdown]
# 프롬프트/파라미터 튜닝

# %%
better_instructions = """
너는 SaaS 서비스 고객센터 티켓을 분류하고 요약하는 AI 어시스턴트다.

역할:
- 사용자의 문의를 읽고, 미리 정의된 카테고리 중 하나로 분류하고
- 상담사가 빠르게 이해할 수 있도록 한국어 한 문장으로 요약한다.
- 또한 티켓의 긴급도를 1~5 사이 정수로 추정한다. (5가 가장 긴급)

카테고리 목록:
- "billing": 결제/환불/요금 관련
- "bug": 오류/버그/접속 문제
- "feature_request": 기능 추가/개선 요청
- "account": 로그인/비밀번호/계정 정보 관련
- "other": 위에 해당하지 않는 기타 문의

출력 형식:
- 반드시 아래 JSON 형식만 출력한다. 추가 설명/자연어 문장은 넣지 마라.
- summary는 한국어 한 문장, 40자 이내로 작성한다.

{
  "category": "billing",
  "summary": "여기에 한국어 한 줄 요약",
  "priority": 3
}
"""

resp_better = analyze_ticket(
    message=sample_ticket,
    instructions=better_instructions,
    temperature=0.2,        # 분류/요약은 안정성이 중요 → 낮게
    top_p=1.0,
    max_output_tokens=120,  # 요약이 길어지지 않게 상한 조절
)
# Out:
# === 원문 응답(output_text) ===
# {
#   "category": "billing",
#   "summary": "결제가 두 번 된 것 같아 확인 요청합니다.",
#   "priority": 4
# }

# %% [markdown]
# 검증/분석

# %%
category_only_instructions = """
너는 고객 문의를 읽고 카테고리를 분류하는 분류기다.

카테고리 목록:
- "billing"
- "bug"
- "feature_request"
- "account"
- "other"

규칙:
- 위 카테고리 문자열 중 하나만 출력해라.
- 따옴표나 마침표 등 다른 문자는 넣지 마라.
"""
resp_logprobs = analyze_ticket(
    message=sample_ticket,
    instructions=category_only_instructions,
    temperature=0.7,             # 가장 확률 높은 토큰만 선택
    top_p=1.0,
    max_output_tokens=20,
    top_logprobs=5,
    include_logprobs=True,
)
probs = resp_logprobs.output[0].content[0].logprobs
print(probs)
for tokenprob in probs:
  print("토큰: {}, 로그확률: {:.3f}, 확률: {:.3f}".format(tokenprob.token, tokenprob.logprob, math.exp(tokenprob.logprob)))
  for candidate in tokenprob.top_logprobs:
    print("\t후보 토큰: {}, 로그확률: {:.3f}, 확률: {:.3f}".format(candidate.token, candidate.logprob, math.exp(candidate.logprob)))
# Out:
# === 원문 응답(output_text) ===
# billing
#
# [Logprob(token='billing', bytes=[98, 105, 108, 108, 105, 110, 103], logprob=-0.0, top_logprobs=[LogprobTopLogprob(token='billing', bytes=[98, 105, 108, 108, 105, 110, 103], logprob=-0.0), LogprobTopLogprob(token=' billing', bytes=[32, 98, 105, 108, 108, 105, 110, 103], logprob=-16.5), LogprobTopLogprob(token='Billing', bytes=[66, 105, 108, 108, 105, 110, 103], logprob=-18.375), LogprobTopLogprob(token='.billing', bytes=[46, 98, 105, 108, 108, 105, 110, 103], logprob=-18.625), LogprobTopLogprob(token='bill', bytes=[98, 105, 108, 108], logprob=-20.625)])]
# 토큰: billing, 로그확률: -0.000, 확률: 1.000
# 	후보 토큰: billing, 로그확률: -0.000, 확률: 1.000
# 	후보 토큰:  billing, 로그확률: -16.500, 확률: 0.000
# 	후보 토큰: Billing, 로그확률: -18.375, 확률: 0.000
# 	후보 토큰: .billing, 로그확률: -18.625, 확률: 0.000
# 	후보 토큰: bill, 로그확률: -20.625, 확률: 0.000
